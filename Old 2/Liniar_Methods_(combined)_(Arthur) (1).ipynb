# %%
# !pip install -q pyinterval
# Out:
#      |████████████████████████████████| 1.6MB 14.1MB/s
#   Building wheel for pyinterval (setup.py) ... done
#   Building wheel for crlibm (setup.py) ... done

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import queue
import pydot
import json
from interval import interval, inf, imath
from networkx.drawing.nx_pydot import graphviz_layout
from collections import deque, OrderedDict
from google.colab import files
from sympy.solvers import solve
from sympy import Symbol
import math

# %%
def liniar_half(start, end, e):
  print('-----Iteration for [', start, ', ', end, ']')
  check = end - start
  if check <= e:
    print('FOUND X =', start, ' ', end)
    return
  X0 = interval([start, end])
  # function
  f = X0**3 - 6*X0**2 + 11*X0 - 6
  print('F: ', f)
  # if f == 0.0:
  #   liniar_half(start, mid, e)
  #   liniar_half(mid, end, e)
  #   return
  
  mid = (start+end)/2;
  #print('middle: ',  mid)
  if 0 in f:
    liniar_half(start, mid, e)
    liniar_half(mid, end, e)
    return
  
print("Лінійний алгоритм навпіл");
print("x^3 - 6*x^2 + 11*x - 6 = 0");
print("1, 2, 3");
print("[0; 6]");
print("------------");
x1 = 1;
x2 = 2;
x3 = 3;
e = 10**(-2)

a = 0;
b = 6;

liniar_half(a, b, e)
# Out:
# Лінійний алгоритм навпіл
# x^3 - 6*x^2 + 11*x - 6 = 0
# 1, 2, 3
# [0; 6]
# ------------
# -----Iteration for [ 0 ,  6 ]
# F:  interval([-222.0, 276.0])
# -----Iteration for [ 0 ,  3.0 ]
# F:  interval([-60.0, 54.0])
# -----Iteration for [ 0 ,  1.5 ]
# F:  interval([-19.5, 13.875])
# -----Iteration for [ 0 ,  0.75 ]
# F:  interval([-9.375, 2.671875])
# -----Iteration for [ 0 ,  0.375 ]
# F:  interval([-6.84375, -1.822265625])
# -----Iteration for [ 0.375 ,  0.75 ]
# F:  interval([-5.197265625, 1.828125])
# -----Iteration for [ 0.375 ,  0.5625 ]
# F:  interval([-3.720703125, -0.478271484375])
# -----Iteration for [ 0.5625 ,  0.75 ]
# F:  interval([-3.009521484375, 0.7734375])
# -----Iteration for [ 0.5625 ,  0.65625 ]
# F:  interval([-2.218505859375, -0.397064208984375])
# -----Iteration for [ 0.65625 ,  0.75 ]
# F:  interval([-1.873626708984375, 0.087890625])
# -----Iteration for [ 0.65625 ,  0.703125 ]
# F:  interval([-1.464935302734375, -0.5019950866699219])
# -----Iteration for [ 0.703125 ,  0.75 ]
# F:  interval([-1.2930107116699219, -0.29443359375])
# -----Iteration for [ 0.75 ,  1.5 ]
# F:  interval([-10.828125, 10.5])
# -----Iteration for [ 0.75 ,  1.125 ]
# F:  interval([-4.921875, 4.423828125])
# -----Iteration for [ 0.75 ,  0.9375 ]
# F:  interval([-2.6015625, 1.761474609375])
# -----Iteration for [ 0.75 ,  0.84375 ]
# F:  interval([-1.599609375, 0.506927490234375])
# -----Iteration for [ 0.75 ,  0.796875 ]
# F:  interval([-1.13818359375, -0.10335159301757812])
# -----Iteration for [ 0.796875 ,  0.84375 ]
# F:  interval([-0.9998359680175781, 0.071868896484375])
# -----Iteration for [ 0.796875 ,  0.8203125 ]
# F:  interval([-0.7658271789550781, -0.23462247848510742])
# -----Iteration for [ 0.8203125 ,  0.84375 ]
# F:  interval([-0.6960482597351074, -0.155548095703125])
# -----Iteration for [ 0.84375 ,  0.9375 ]
# F:  interval([-1.391510009765625, 0.864990234375])
# -----Iteration for [ 0.84375 ,  0.890625 ]
# F:  interval([-0.877349853515625, 0.23184585571289062])
# -----Iteration for [ 0.84375 ,  0.8671875 ]
# F:  interval([-0.630157470703125, -0.08028459548950195])
# -----Iteration for [ 0.8671875 ,  0.890625 ]
# F:  interval([-0.568077564239502, -0.008754730224609375])
# -----Iteration for [ 0.890625 ,  0.9375 ]
# F:  interval([-0.7701072692871094, 0.377197265625])
# -----Iteration for [ 0.890625 ,  0.9140625 ]
# F:  interval([-0.5097312927246094, 0.05911874771118164])
# -----Iteration for [ 0.890625 ,  0.90234375 ]
# F:  interval([-0.3820152282714844, -0.09878593683242798])
# -----Iteration for [ 0.90234375 ,  0.9140625 ]
# F:  interval([-0.352570116519928, -0.06694936752319336])
# -----Iteration for [ 0.9140625 ,  0.9375 ]
# F:  interval([-0.45504140853881836, 0.1234130859375])
# -----Iteration for [ 0.9140625 ,  0.92578125 ]
# F:  interval([-0.32402944564819336, -0.036007583141326904])
# -----Iteration for [ 0.92578125 ,  0.9375 ]
# F:  interval([-0.2963835597038269, -0.005950927734375])
# -----Iteration for [ 0.9375 ,  1.125 ]
# F:  interval([-2.457275390625, 2.525390625])
# -----Iteration for [ 0.9375 ,  1.03125 ]
# F:  interval([-1.244384765625, 1.167022705078125])
# -----Iteration for [ 0.9375 ,  0.984375 ]
# F:  interval([-0.677490234375, 0.5085411071777344])
# -----Iteration for [ 0.9375 ,  0.9609375 ]
# F:  interval([-0.4039306640625, 0.1842055320739746])
# -----Iteration for [ 0.9375 ,  0.94921875 ]
# F:  interval([-0.269622802734375, 0.023230254650115967])
# -----Iteration for [ 0.9375 ,  0.943359375 ]
# FOUND X = 0.9375   0.943359375
# -----Iteration for [ 0.943359375 ,  0.94921875 ]
# FOUND X = 0.943359375   0.94921875
# -----Iteration for [ 0.94921875 ,  0.9609375 ]
# F:  interval([-0.24373751878738403, 0.05154561996459961])
# -----Iteration for [ 0.94921875 ,  0.955078125 ]
# FOUND X = 0.94921875   0.955078125
# -----Iteration for [ 0.955078125 ,  0.9609375 ]
# FOUND X = 0.955078125   0.9609375
# -----Iteration for [ 0.9609375 ,  0.984375 ]
# F:  interval([-0.3563218116760254, 0.24157333374023438])
# -----Iteration for [ 0.9609375 ,  0.97265625 ]
# F:  interval([-0.2187180519104004, 0.07900482416152954])
# -----Iteration for [ 0.9609375 ,  0.966796875 ]
# FOUND X = 0.9609375   0.966796875
# -----Iteration for [ 0.966796875 ,  0.97265625 ]
# FOUND X = 0.966796875   0.97265625
# -----Iteration for [ 0.97265625 ,  0.984375 ]
# F:  interval([-0.19455474615097046, 0.10561752319335938])
# -----Iteration for [ 0.97265625 ,  0.978515625 ]
# FOUND X = 0.97265625   0.978515625
# -----Iteration for [ 0.978515625 ,  0.984375 ]
# FOUND X = 0.978515625   0.984375
# -----Iteration for [ 0.984375 ,  1.03125 ]
# F:  interval([-0.5988807678222656, 0.626495361328125])
# -----Iteration for [ 0.984375 ,  1.0078125 ]
# F:  interval([-0.3121376037597656, 0.2955937385559082])
# -----Iteration for [ 0.984375 ,  0.99609375 ]
# F:  interval([-0.17123794555664062, 0.13139337301254272])
# -----Iteration for [ 0.984375 ,  0.990234375 ]
# FOUND X = 0.984375   0.990234375
# -----Iteration for [ 0.990234375 ,  0.99609375 ]
# FOUND X = 0.990234375   0.99609375
# -----Iteration for [ 0.99609375 ,  1.0078125 ]
# F:  interval([-0.14875799417495728, 0.1563420295715332])
# -----Iteration for [ 0.99609375 ,  1.001953125 ]
# FOUND X = 0.99609375   1.001953125
# -----Iteration for [ 1.001953125 ,  1.0078125 ]
# FOUND X = 1.001953125   1.0078125
# -----Iteration for [ 1.0078125 ,  1.03125 ]
# F:  interval([-0.2713007926940918, 0.346343994140625])
# -----Iteration for [ 1.0078125 ,  1.01953125 ]
# F:  interval([-0.1271052360534668, 0.18047314882278442])
# -----Iteration for [ 1.0078125 ,  1.013671875 ]
# FOUND X = 1.0078125   1.013671875
# -----Iteration for [ 1.013671875 ,  1.01953125 ]
# FOUND X = 1.013671875   1.01953125
# -----Iteration for [ 1.01953125 ,  1.03125 ]
# F:  interval([-0.10627001523971558, 0.20379638671875])
# -----Iteration for [ 1.01953125 ,  1.025390625 ]
# FOUND X = 1.01953125   1.025390625
# -----Iteration for [ 1.025390625 ,  1.03125 ]
# FOUND X = 1.025390625   1.03125
# -----Iteration for [ 1.03125 ,  1.125 ]
# F:  interval([-1.153289794921875, 1.41796875])
# -----Iteration for [ 1.03125 ,  1.078125 ]
# F:  interval([-0.533660888671875, 0.7316780090332031])
# -----Iteration for [ 1.03125 ,  1.0546875 ]
# F:  interval([-0.233734130859375, 0.39390134811401367])
# -----Iteration for [ 1.03125 ,  1.04296875 ]
# F:  interval([-0.08624267578125, 0.22632139921188354])
# -----Iteration for [ 1.03125 ,  1.037109375 ]
# FOUND X = 1.03125   1.037109375
# -----Iteration for [ 1.037109375 ,  1.04296875 ]
# FOUND X = 1.037109375   1.04296875
# -----Iteration for [ 1.04296875 ,  1.0546875 ]
# F:  interval([-0.06701356172561646, 0.24805784225463867])
# -----Iteration for [ 1.04296875 ,  1.048828125 ]
# FOUND X = 1.04296875   1.048828125
# -----Iteration for [ 1.048828125 ,  1.0546875 ]
# FOUND X = 1.048828125   1.0546875
# -----Iteration for [ 1.0546875 ,  1.078125 ]
# F:  interval([-0.19936037063598633, 0.4383430480957031])
# -----Iteration for [ 1.0546875 ,  1.06640625 ]
# F:  interval([-0.04857301712036133, 0.269015371799469])
# -----Iteration for [ 1.0546875 ,  1.060546875 ]
# FOUND X = 1.0546875   1.060546875
# -----Iteration for [ 1.060546875 ,  1.06640625 ]
# FOUND X = 1.060546875   1.06640625
# -----Iteration for [ 1.06640625 ,  1.078125 ]
# F:  interval([-0.030911386013031006, 0.2892036437988281])
# -----Iteration for [ 1.06640625 ,  1.072265625 ]
# FOUND X = 1.06640625   1.072265625
# -----Iteration for [ 1.072265625 ,  1.078125 ]
# FOUND X = 1.072265625   1.078125
# -----Iteration for [ 1.078125 ,  1.125 ]
# F:  interval([-0.4812126159667969, 0.82470703125])
# -----Iteration for [ 1.078125 ,  1.1015625 ]
# F:  interval([-0.16810226440429688, 0.47974634170532227])
# -----Iteration for [ 1.078125 ,  1.08984375 ]
# F:  interval([-0.014019012451171875, 0.3086323142051697])
# -----Iteration for [ 1.078125 ,  1.083984375 ]
# FOUND X = 1.078125   1.083984375
# -----Iteration for [ 1.083984375 ,  1.08984375 ]
# FOUND X = 1.083984375   1.08984375
# -----Iteration for [ 1.08984375 ,  1.1015625 ]
# F:  interval([0.0021137595176696777, 0.32731103897094727])
# -----Iteration for [ 1.1015625 ,  1.125 ]
# F:  interval([-0.13988256454467773, 0.5181884765625])
# -----Iteration for [ 1.1015625 ,  1.11328125 ]
# F:  interval([0.017496585845947266, 0.3452494740486145])
# -----Iteration for [ 1.11328125 ,  1.125 ]
# F:  interval([0.0321391224861145, 0.362457275390625])
# -----Iteration for [ 1.125 ,  1.5 ]
# F:  interval([-5.701171875, 6.28125])
# -----Iteration for [ 1.125 ,  1.3125 ]
# F:  interval([-2.537109375, 3.104736328125])
# -----Iteration for [ 1.125 ,  1.21875 ]
# F:  interval([-1.11328125, 1.622772216796875])
# -----Iteration for [ 1.125 ,  1.171875 ]
# F:  interval([-0.44091796875, 0.9062004089355469])
# -----Iteration for [ 1.125 ,  1.1484375 ]
# F:  interval([-0.1146240234375, 0.5537467002868652])
# -----Iteration for [ 1.125 ,  1.13671875 ]
# F:  interval([0.046051025390625, 0.3789440989494324])
# -----Iteration for [ 1.13671875 ,  1.1484375 ]
# F:  interval([0.05924195051193237, 0.39471960067749023])
# -----Iteration for [ 1.1484375 ,  1.171875 ]
# F:  interval([-0.09224939346313477, 0.5864982604980469])
# -----Iteration for [ 1.1484375 ,  1.16015625 ]
# F:  interval([0.07172155380249023, 0.4097934365272522])
# -----Iteration for [ 1.16015625 ,  1.171875 ]
# F:  interval([0.0834994912147522, 0.4241752624511719])
# -----Iteration for [ 1.171875 ,  1.21875 ]
# F:  interval([-0.4121589660644531, 0.976776123046875])
# -----Iteration for [ 1.171875 ,  1.1953125 ]
# F:  interval([-0.07268142700195312, 0.6165204048156738])
# -----Iteration for [ 1.171875 ,  1.18359375 ]
# F:  interval([0.09458541870117188, 0.4378747344017029])
# -----Iteration for [ 1.18359375 ,  1.1953125 ]
# F:  interval([0.10498899221420288, 0.45090150833129883])
# -----Iteration for [ 1.1953125 ,  1.21875 ]
# F:  interval([-0.05584287643432617, 0.643890380859375])
# -----Iteration for [ 1.1953125 ,  1.20703125 ]
# F:  interval([0.11471986770629883, 0.46326524019241333])
# -----Iteration for [ 1.20703125 ,  1.21875 ]
# F:  interval([0.12378770112991333, 0.4749755859375])
# -----Iteration for [ 1.21875 ,  1.3125 ]
# F:  interval([-1.119415283203125, 1.786376953125])
# -----Iteration for [ 1.21875 ,  1.265625 ]
# F:  interval([-0.394317626953125, 1.0370521545410156])
# -----Iteration for [ 1.21875 ,  1.2421875 ]
# F:  interval([-0.041656494140625, 0.6686854362487793])
# -----Iteration for [ 1.21875 ,  1.23046875 ]
# F:  interval([0.1322021484375, 0.48604220151901245])
# -----Iteration for [ 1.23046875 ,  1.2421875 ]
# F:  interval([0.13997286558151245, 0.4964747428894043])
# -----Iteration for [ 1.2421875 ,  1.265625 ]
# F:  interval([-0.030045032501220703, 0.6909828186035156])
# -----Iteration for [ 1.2421875 ,  1.25390625 ]
# F:  interval([0.1471095085144043, 0.5062828660011292])
# -----Iteration for [ 1.25390625 ,  1.265625 ]
# F:  interval([0.15362173318862915, 0.5154762268066406])
# -----Iteration for [ 1.265625 ,  1.3125 ]
# F:  interval([-0.3867759704589844, 1.087646484375])
# -----Iteration for [ 1.265625 ,  1.2890625 ]
# F:  interval([-0.020931243896484375, 0.7108597755432129])
# -----Iteration for [ 1.265625 ,  1.27734375 ]
# F:  interval([0.15951919555664062, 0.5240644812583923])
# -----Iteration for [ 1.27734375 ,  1.2890625 ]
# F:  interval([0.16481155157089233, 0.5320572853088379])
# -----Iteration for [ 1.2890625 ,  1.3125 ]
# F:  interval([-0.01423788070678711, 0.7283935546875])
# -----Iteration for [ 1.2890625 ,  1.30078125 ]
# F:  interval([0.1695084571838379, 0.5394642949104309])
# -----Iteration for [ 1.30078125 ,  1.3125 ]
# F:  interval([0.1736195683479309, 0.546295166015625])
# -----Iteration for [ 1.3125 ,  1.5 ]
# F:  interval([-2.801513671875, 3.5390625])
# -----Iteration for [ 1.3125 ,  1.40625 ]
# F:  interval([-1.166748046875, 1.913726806640625])
# -----Iteration for [ 1.3125 ,  1.359375 ]
# F:  interval([-0.388916015625, 1.1291770935058594])
# -----Iteration for [ 1.3125 ,  1.3359375 ]
# F:  interval([-0.0098876953125, 0.7436614036560059])
# -----Iteration for [ 1.3125 ,  1.32421875 ]
# F:  interval([0.177154541015625, 0.5525595545768738])
# -----Iteration for [ 1.32421875 ,  1.3359375 ]
# F:  interval([0.18012303113937378, 0.5582671165466309])
# -----Iteration for [ 1.3359375 ,  1.359375 ]
# F:  interval([-0.007803440093994141, 0.7567405700683594])
# -----Iteration for [ 1.3359375 ,  1.34765625 ]
# F:  interval([0.18253469467163086, 0.5634275078773499])
# -----Iteration for [ 1.34765625 ,  1.359375 ]
# F:  interval([0.18439918756484985, 0.5680503845214844])
# -----Iteration for [ 1.359375 ,  1.40625 ]
# F:  interval([-0.4001197814941406, 1.162261962890625])
# -----Iteration for [ 1.359375 ,  1.3828125 ]
# F:  interval([-0.007907867431640625, 0.7677083015441895])
# -----Iteration for [ 1.359375 ,  1.37109375 ]
# F:  interval([0.18572616577148438, 0.572145402431488])
# -----Iteration for [ 1.37109375 ,  1.3828125 ]
# F:  interval([0.18652528524398804, 0.5757222175598145])
# -----Iteration for [ 1.3828125 ,  1.40625 ]
# F:  interval([-0.010123729705810547, 0.776641845703125])
# -----Iteration for [ 1.3828125 ,  1.39453125 ]
# F:  interval([0.18680620193481445, 0.5787904858589172])
# -----Iteration for [ 1.39453125 ,  1.40625 ]
# F:  interval([0.18657857179641724, 0.58135986328125])
# -----Iteration for [ 1.40625 ,  1.5 ]
# F:  interval([-1.250335693359375, 2.009765625])
# -----Iteration for [ 1.40625 ,  1.453125 ]
# F:  interval([-0.419769287109375, 1.1875190734863281])
# -----Iteration for [ 1.40625 ,  1.4296875 ]
# F:  interval([-0.014373779296875, 0.7836184501647949])
# -----Iteration for [ 1.40625 ,  1.41796875 ]
# F:  interval([0.18585205078125, 0.5834400057792664])
# -----Iteration for [ 1.41796875 ,  1.4296875 ]
# F:  interval([0.18463629484176636, 0.5850405693054199])
# -----Iteration for [ 1.4296875 ,  1.453125 ]
# F:  interval([-0.020580768585205078, 0.7887153625488281])
# -----Iteration for [ 1.4296875 ,  1.44140625 ]
# F:  interval([0.18294095993041992, 0.5861712098121643])
# -----Iteration for [ 1.44140625 ,  1.453125 ]
# F:  interval([0.1807757019996643, 0.5868415832519531])
# -----Iteration for [ 1.453125 ,  1.5 ]
# F:  interval([-0.4472465515136719, 1.20556640625])
# -----Iteration for [ 1.453125 ,  1.4765625 ]
# F:  interval([-0.028667449951171875, 0.7920098304748535])
# -----Iteration for [ 1.453125 ,  1.46484375 ]
# F:  interval([0.17815017700195312, 0.58706134557724])
# -----Iteration for [ 1.46484375 ,  1.4765625 ]
# F:  interval([0.17507404088974, 0.5868401527404785])
# -----Iteration for [ 1.4765625 ,  1.5 ]
# F:  interval([-0.038556575775146484, 0.7935791015625])
# -----Iteration for [ 1.4765625 ,  1.48828125 ]
# F:  interval([0.17155694961547852, 0.5861876606941223])
# -----Iteration for [ 1.48828125 ,  1.5 ]
# F:  interval([0.16760855913162231, 0.585113525390625])
# -----Iteration for [ 1.5 ,  3.0 ]
# F:  interval([-40.125, 40.5])
# -----Iteration for [ 1.5 ,  2.25 ]
# F:  interval([-16.5, 16.640625])
# -----Iteration for [ 1.5 ,  1.875 ]
# F:  interval([-7.21875, 7.716796875])
# -----Iteration for [ 1.5 ,  1.6875 ]
# F:  interval([-3.2109375, 3.867919921875])
# -----Iteration for [ 1.5 ,  1.59375 ]
# F:  interval([-1.365234375, 2.079437255859375])
# -----Iteration for [ 1.5 ,  1.546875 ]
# F:  interval([-0.48193359375, 1.2170219421386719])
# -----Iteration for [ 1.5 ,  1.5234375 ]
# F:  interval([-0.0501708984375, 0.7935004234313965])
# -----Iteration for [ 1.5 ,  1.51171875 ]
# F:  interval([0.163238525390625, 0.5836274027824402])
# -----Iteration for [ 1.51171875 ,  1.5234375 ]
# F:  interval([0.15845650434494019, 0.5817389488220215])
# -----Iteration for [ 1.5234375 ,  1.546875 ]
# F:  interval([-0.06343317031860352, 0.7918510437011719])
# -----Iteration for [ 1.5234375 ,  1.53515625 ]
# F:  interval([0.15327215194702148, 0.5794578194618225])
# -----Iteration for [ 1.53515625 ,  1.546875 ]
# F:  interval([0.1476951241493225, 0.5767936706542969])
# -----Iteration for [ 1.546875 ,  1.59375 ]
# F:  interval([-0.5232124328613281, 1.222503662109375])
# -----Iteration for [ 1.546875 ,  1.5703125 ]
# F:  interval([-0.07826614379882812, 0.7887082099914551])
# -----Iteration for [ 1.546875 ,  1.55859375 ]
# F:  interval([0.14173507690429688, 0.5737561583518982])
# -----Iteration for [ 1.55859375 ,  1.5703125 ]
# F:  interval([0.1354016661643982, 0.5703549385070801])
# -----Iteration for [ 1.5703125 ,  1.59375 ]
# F:  interval([-0.09459257125854492, 0.784149169921875])
# -----Iteration for [ 1.5703125 ,  1.58203125 ]
# F:  interval([0.12870454788208008, 0.5665996670722961])
# -----Iteration for [ 1.58203125 ,  1.59375 ]
# F:  interval([0.12165337800979614, 0.5625])
# -----Iteration for [ 1.59375 ,  1.6875 ]
# F:  interval([-1.506500244140625, 2.127685546875])
# -----Iteration for [ 1.59375 ,  1.640625 ]
# F:  interval([-0.570465087890625, 1.2226295471191406])
# -----Iteration for [ 1.59375 ,  1.6171875 ]
# F:  interval([-0.112335205078125, 0.7782511711120605])
# -----Iteration for [ 1.59375 ,  1.60546875 ]
# F:  interval([0.1142578125, 0.5580655932426453])
# -----Iteration for [ 1.60546875 ,  1.6171875 ]
# F:  interval([0.10652750730514526, 0.5533061027526855])
# -----Iteration for [ 1.6171875 ,  1.640625 ]
# F:  interval([-0.13141679763793945, 0.7710914611816406])
# -----Iteration for [ 1.6171875 ,  1.62890625 ]
# F:  interval([0.09847211837768555, 0.5482311844825745])
# -----Iteration for [ 1.62890625 ,  1.640625 ]
# F:  interval([0.09010130167007446, 0.5428504943847656])
# -----Iteration for [ 1.640625 ,  1.6875 ]
# F:  interval([-0.6230735778808594, 1.218017578125])
# -----Iteration for [ 1.640625 ,  1.6640625 ]
# F:  interval([-0.15176010131835938, 0.7627472877502441])
# -----Iteration for [ 1.640625 ,  1.65234375 ]
# F:  interval([0.08142471313476562, 0.5371736884117126])
# -----Iteration for [ 1.65234375 ,  1.6640625 ]
# F:  interval([0.07245200872421265, 0.5312104225158691])
# -----Iteration for [ 1.6640625 ,  1.6875 ]
# F:  interval([-0.17328786849975586, 0.7532958984375])
# -----Iteration for [ 1.6640625 ,  1.67578125 ]
# F:  interval([0.06319284439086914, 0.5249703526496887])
# -----Iteration for [ 1.67578125 ,  1.6875 ]
# F:  interval([0.05365687608718872, 0.518463134765625])
# -----Iteration for [ 1.6875 ,  1.875 ]
# F:  interval([-3.725830078125, 4.130859375])
# -----Iteration for [ 1.6875 ,  1.78125 ]
# F:  interval([-1.669189453125, 2.159454345703125])
# -----Iteration for [ 1.6875 ,  1.734375 ]
# F:  interval([-0.680419921875, 1.2092857360839844])
# -----Iteration for [ 1.6875 ,  1.7109375 ]
# F:  interval([-0.1959228515625, 0.7428145408630371])
# -----Iteration for [ 1.6875 ,  1.69921875 ]
# F:  interval([0.043853759765625, 0.5116984248161316])
# -----Iteration for [ 1.69921875 ,  1.7109375 ]
# F:  interval([0.03379315137863159, 0.5046858787536621])
# -----Iteration for [ 1.7109375 ,  1.734375 ]
# F:  interval([-0.2195878028869629, 0.7313804626464844])
# -----Iteration for [ 1.7109375 ,  1.72265625 ]
# F:  interval([0.02348470687866211, 0.49743515253067017])
# -----Iteration for [ 1.72265625 ,  1.734375 ]
# F:  interval([0.012938082218170166, 0.4899559020996094])
# -----Iteration for [ 1.734375 ,  1.78125 ]
# F:  interval([-0.7418861389160156, 1.197052001953125])
# -----Iteration for [ 1.734375 ,  1.7578125 ]
# F:  interval([-0.24420547485351562, 0.7190709114074707])
# -----Iteration for [ 1.734375 ,  1.74609375 ]
# F:  interval([0.002162933349609375, 0.48225778341293335])
# -----Iteration for [ 1.74609375 ,  1.7578125 ]
# F:  interval([-0.00883108377456665, 0.4743504524230957])
# -----Iteration for [ 1.74609375 ,  1.751953125 ]
# FOUND X = 1.74609375   1.751953125
# -----Iteration for [ 1.751953125 ,  1.7578125 ]
# FOUND X = 1.751953125   1.7578125
# -----Iteration for [ 1.7578125 ,  1.78125 ]
# F:  interval([-0.2696986198425293, 0.705963134765625])
# -----Iteration for [ 1.7578125 ,  1.76953125 ]
# F:  interval([-0.020034313201904297, 0.46624356508255005])
# -----Iteration for [ 1.7578125 ,  1.763671875 ]
# FOUND X = 1.7578125   1.763671875
# -----Iteration for [ 1.763671875 ,  1.76953125 ]
# FOUND X = 1.763671875   1.76953125
# -----Iteration for [ 1.76953125 ,  1.78125 ]
# F:  interval([-0.03143709897994995, 0.45794677734375])
# -----Iteration for [ 1.76953125 ,  1.775390625 ]
# FOUND X = 1.76953125   1.775390625
# -----Iteration for [ 1.775390625 ,  1.78125 ]
# FOUND X = 1.775390625   1.78125
# -----Iteration for [ 1.78125 ,  1.875 ]
# F:  interval([-1.848358154296875, 2.1796875])
# -----Iteration for [ 1.78125 ,  1.828125 ]
# F:  interval([-0.806854248046875, 1.1819343566894531])
# -----Iteration for [ 1.78125 ,  1.8046875 ]
# F:  interval([-0.295989990234375, 0.6921343803405762])
# -----Iteration for [ 1.78125 ,  1.79296875 ]
# F:  interval([-0.04302978515625, 0.44946974515914917])
# -----Iteration for [ 1.78125 ,  1.787109375 ]
# FOUND X = 1.78125   1.787109375
# -----Iteration for [ 1.787109375 ,  1.79296875 ]
# FOUND X = 1.787109375   1.79296875
# -----Iteration for [ 1.79296875 ,  1.8046875 ]
# F:  interval([-0.05480271577835083, 0.44082212448120117])
# -----Iteration for [ 1.79296875 ,  1.798828125 ]
# FOUND X = 1.79296875   1.798828125
# -----Iteration for [ 1.798828125 ,  1.8046875 ]
# FOUND X = 1.798828125   1.8046875
# -----Iteration for [ 1.8046875 ,  1.828125 ]
# F:  interval([-0.32300233840942383, 0.6776618957519531])
# -----Iteration for [ 1.8046875 ,  1.81640625 ]
# F:  interval([-0.06674623489379883, 0.4320135712623596])
# -----Iteration for [ 1.8046875 ,  1.810546875 ]
# FOUND X = 1.8046875   1.810546875
# -----Iteration for [ 1.810546875 ,  1.81640625 ]
# FOUND X = 1.810546875   1.81640625
# -----Iteration for [ 1.81640625 ,  1.828125 ]
# F:  interval([-0.07885068655014038, 0.4230537414550781])
# -----Iteration for [ 1.81640625 ,  1.822265625 ]
# FOUND X = 1.81640625   1.822265625
# -----Iteration for [ 1.822265625 ,  1.828125 ]
# FOUND X = 1.822265625   1.828125
# -----Iteration for [ 1.828125 ,  1.875 ]
# F:  interval([-0.8747062683105469, 1.16455078125])
# -----Iteration for [ 1.828125 ,  1.8515625 ]
# F:  interval([-0.3506584167480469, 0.6626229286193848])
# -----Iteration for [ 1.828125 ,  1.83984375 ]
# F:  interval([-0.09110641479492188, 0.4139522910118103])
# -----Iteration for [ 1.828125 ,  1.833984375 ]
# FOUND X = 1.828125   1.833984375
# -----Iteration for [ 1.833984375 ,  1.83984375 ]
# FOUND X = 1.833984375   1.83984375
# -----Iteration for [ 1.83984375 ,  1.8515625 ]
# F:  interval([-0.1035037636756897, 0.40471887588500977])
# -----Iteration for [ 1.83984375 ,  1.845703125 ]
# FOUND X = 1.83984375   1.845703125
# -----Iteration for [ 1.845703125 ,  1.8515625 ]
# FOUND X = 1.845703125   1.8515625
# -----Iteration for [ 1.8515625 ,  1.875 ]
# F:  interval([-0.37888097763061523, 0.6470947265625])
# -----Iteration for [ 1.8515625 ,  1.86328125 ]
# F:  interval([-0.11603307723999023, 0.3953631520271301])
# -----Iteration for [ 1.8515625 ,  1.857421875 ]
# FOUND X = 1.8515625   1.857421875
# -----Iteration for [ 1.857421875 ,  1.86328125 ]
# FOUND X = 1.857421875   1.86328125
# -----Iteration for [ 1.86328125 ,  1.875 ]
# F:  interval([-0.12868469953536987, 0.385894775390625])
# -----Iteration for [ 1.86328125 ,  1.869140625 ]
# FOUND X = 1.86328125   1.869140625
# -----Iteration for [ 1.869140625 ,  1.875 ]
# FOUND X = 1.869140625   1.875
# -----Iteration for [ 1.875 ,  2.25 ]
# F:  interval([-9.158203125, 9.046875])
# -----Iteration for [ 1.875 ,  2.0625 ]
# F:  interval([-4.306640625, 4.367431640625])
# -----Iteration for [ 1.875 ,  1.96875 ]
# F:  interval([-2.0390625, 2.193328857421875])
# -----Iteration for [ 1.875 ,  1.921875 ]
# F:  interval([-0.94482421875, 1.1455192565917969])
# -----Iteration for [ 1.875 ,  1.8984375 ]
# F:  interval([-0.4075927734375, 0.6311545372009277])
# -----Iteration for [ 1.875 ,  1.88671875 ]
# F:  interval([-0.141448974609375, 0.376323401927948])
# -----Iteration for [ 1.875 ,  1.880859375 ]
# FOUND X = 1.875   1.880859375
# -----Iteration for [ 1.880859375 ,  1.88671875 ]
# FOUND X = 1.880859375   1.88671875
# -----Iteration for [ 1.88671875 ,  1.8984375 ]
# F:  interval([-0.154316246509552, 0.36665868759155273])
# -----Iteration for [ 1.88671875 ,  1.892578125 ]
# FOUND X = 1.88671875   1.892578125
# -----Iteration for [ 1.892578125 ,  1.8984375 ]
# FOUND X = 1.892578125   1.8984375
# -----Iteration for [ 1.8984375 ,  1.921875 ]
# F:  interval([-0.43671655654907227, 0.6148796081542969])
# -----Iteration for [ 1.8984375 ,  1.91015625 ]
# F:  interval([-0.16727685928344727, 0.3569102883338928])
# -----Iteration for [ 1.8984375 ,  1.904296875 ]
# FOUND X = 1.8984375   1.904296875
# -----Iteration for [ 1.904296875 ,  1.91015625 ]
# FOUND X = 1.904296875   1.91015625
# -----Iteration for [ 1.91015625 ,  1.921875 ]
# F:  interval([-0.18032115697860718, 0.3470878601074219])
# -----Iteration for [ 1.91015625 ,  1.916015625 ]
# FOUND X = 1.91015625   1.916015625
# -----Iteration for [ 1.916015625 ,  1.921875 ]
# FOUND X = 1.916015625   1.921875
# -----Iteration for [ 1.921875 ,  1.96875 ]
# F:  interval([-1.0165901184082031, 1.125457763671875])
# -----Iteration for [ 1.921875 ,  1.9453125 ]
# F:  interval([-0.4661750793457031, 0.5983471870422363])
# -----Iteration for [ 1.921875 ,  1.93359375 ]
# F:  interval([-0.19343948364257812, 0.3372010588645935])
# -----Iteration for [ 1.921875 ,  1.927734375 ]
# FOUND X = 1.921875   1.927734375
# -----Iteration for [ 1.927734375 ,  1.93359375 ]
# FOUND X = 1.927734375   1.93359375
# -----Iteration for [ 1.93359375 ,  1.9453125 ]
# F:  interval([-0.2066221833229065, 0.32725954055786133])
# -----Iteration for [ 1.93359375 ,  1.939453125 ]
# FOUND X = 1.93359375   1.939453125
# -----Iteration for [ 1.939453125 ,  1.9453125 ]
# FOUND X = 1.939453125   1.9453125
# -----Iteration for [ 1.9453125 ,  1.96875 ]
# F:  interval([-0.49589109420776367, 0.581634521484375])
# -----Iteration for [ 1.9453125 ,  1.95703125 ]
# F:  interval([-0.21985960006713867, 0.31727296113967896])
# -----Iteration for [ 1.9453125 ,  1.951171875 ]
# FOUND X = 1.9453125   1.951171875
# -----Iteration for [ 1.951171875 ,  1.95703125 ]
# FOUND X = 1.951171875   1.95703125
# -----Iteration for [ 1.95703125 ,  1.96875 ]
# F:  interval([-0.23314207792282104, 0.3072509765625])
# -----Iteration for [ 1.95703125 ,  1.962890625 ]
# FOUND X = 1.95703125   1.962890625
# -----Iteration for [ 1.962890625 ,  1.96875 ]
# FOUND X = 1.962890625   1.96875
# -----Iteration for [ 1.96875 ,  2.0625 ]
# F:  interval([-2.236358642578125, 2.205322265625])
# -----Iteration for [ 1.96875 ,  2.015625 ]
# F:  interval([-1.089385986328125, 1.1049842834472656])
# -----Iteration for [ 1.96875 ,  1.9921875 ]
# F:  interval([-0.525787353515625, 0.5648188591003418])
# -----Iteration for [ 1.96875 ,  1.98046875 ]
# F:  interval([-0.2464599609375, 0.2972032427787781])
# -----Iteration for [ 1.96875 ,  1.974609375 ]
# FOUND X = 1.96875   1.974609375
# -----Iteration for [ 1.974609375 ,  1.98046875 ]
# FOUND X = 1.974609375   1.98046875
# -----Iteration for [ 1.98046875 ,  1.9921875 ]
# F:  interval([-0.2598035931587219, 0.2871394157409668])
# -----Iteration for [ 1.98046875 ,  1.986328125 ]
# FOUND X = 1.98046875   1.986328125
# -----Iteration for [ 1.986328125 ,  1.9921875 ]
# FOUND X = 1.986328125   1.9921875
# -----Iteration for [ 1.9921875 ,  2.015625 ]
# F:  interval([-0.5557866096496582, 0.5479774475097656])
# -----Iteration for [ 1.9921875 ,  2.00390625 ]
# F:  interval([-0.2731633186340332, 0.2770691514015198])
# -----Iteration for [ 1.9921875 ,  1.998046875 ]
# FOUND X = 1.9921875   1.998046875
# -----Iteration for [ 1.998046875 ,  2.00390625 ]
# FOUND X = 1.998046875   2.00390625
# -----Iteration for [ 2.00390625 ,  2.015625 ]
# F:  interval([-0.2865294814109802, 0.2670021057128906])
# -----Iteration for [ 2.00390625 ,  2.009765625 ]
# FOUND X = 2.00390625   2.009765625
# -----Iteration for [ 2.009765625 ,  2.015625 ]
# FOUND X = 2.009765625   2.015625
# -----Iteration for [ 2.015625 ,  2.0625 ]
# F:  interval([-1.1625938415527344, 1.084716796875])
# -----Iteration for [ 2.015625 ,  2.0390625 ]
# F:  interval([-0.5858116149902344, 0.5311875343322754])
# -----Iteration for [ 2.015625 ,  2.02734375 ]
# F:  interval([-0.2998924255371094, 0.25694793462753296])
# -----Iteration for [ 2.015625 ,  2.021484375 ]
# FOUND X = 2.015625   2.021484375
# -----Iteration for [ 2.021484375 ,  2.02734375 ]
# FOUND X = 2.021484375   2.02734375
# -----Iteration for [ 2.02734375 ,  2.0390625 ]
# F:  interval([-0.31324249505996704, 0.2469162940979004])
# -----Iteration for [ 2.02734375 ,  2.033203125 ]
# FOUND X = 2.02734375   2.033203125
# -----Iteration for [ 2.033203125 ,  2.0390625 ]
# FOUND X = 2.033203125   2.0390625
# -----Iteration for [ 2.0390625 ,  2.0625 ]
# F:  interval([-0.6157851219177246, 0.5145263671875])
# -----Iteration for [ 2.0390625 ,  2.05078125 ]
# F:  interval([-0.3265700340270996, 0.23691684007644653])
# -----Iteration for [ 2.0390625 ,  2.044921875 ]
# FOUND X = 2.0390625   2.044921875
# -----Iteration for [ 2.044921875 ,  2.05078125 ]
# FOUND X = 2.044921875   2.05078125
# -----Iteration for [ 2.05078125 ,  2.0625 ]
# F:  interval([-0.33986538648605347, 0.226959228515625])
# -----Iteration for [ 2.05078125 ,  2.056640625 ]
# FOUND X = 2.05078125   2.056640625
# -----Iteration for [ 2.056640625 ,  2.0625 ]
# FOUND X = 2.056640625   2.0625
# -----Iteration for [ 2.0625 ,  2.25 ]
# F:  interval([-4.913818359375, 4.6171875])
# -----Iteration for [ 2.0625 ,  2.15625 ]
# F:  interval([-2.435302734375, 2.220611572265625])
# -----Iteration for [ 2.0625 ,  2.109375 ]
# F:  interval([-1.235595703125, 1.0652732849121094])
# -----Iteration for [ 2.0625 ,  2.0859375 ]
# F:  interval([-0.6456298828125, 0.49807119369506836])
# -----Iteration for [ 2.0625 ,  2.07421875 ]
# F:  interval([-0.353118896484375, 0.2170531153678894])
# -----Iteration for [ 2.0625 ,  2.068359375 ]
# FOUND X = 2.0625   2.068359375
# -----Iteration for [ 2.068359375 ,  2.07421875 ]
# FOUND X = 2.068359375   2.07421875
# -----Iteration for [ 2.07421875 ,  2.0859375 ]
# F:  interval([-0.3663209080696106, 0.20720815658569336])
# -----Iteration for [ 2.07421875 ,  2.080078125 ]
# FOUND X = 2.07421875   2.080078125
# -----Iteration for [ 2.080078125 ,  2.0859375 ]
# FOUND X = 2.080078125   2.0859375
# -----Iteration for [ 2.0859375 ,  2.109375 ]
# F:  interval([-0.6752686500549316, 0.4818992614746094])
# -----Iteration for [ 2.0859375 ,  2.09765625 ]
# F:  interval([-0.37946176528930664, 0.19743400812149048])
# -----Iteration for [ 2.0859375 ,  2.091796875 ]
# FOUND X = 2.0859375   2.091796875
# -----Iteration for [ 2.091796875 ,  2.09765625 ]
# FOUND X = 2.091796875   2.09765625
# -----Iteration for [ 2.09765625 ,  2.109375 ]
# F:  interval([-0.3925318121910095, 0.18774032592773438])
# -----Iteration for [ 2.09765625 ,  2.103515625 ]
# FOUND X = 2.09765625   2.103515625
# -----Iteration for [ 2.103515625 ,  2.109375 ]
# FOUND X = 2.103515625   2.109375
# -----Iteration for [ 2.109375 ,  2.15625 ]
# F:  interval([-1.3077735900878906, 1.047271728515625])
# -----Iteration for [ 2.109375 ,  2.1328125 ]
# F:  interval([-0.7046241760253906, 0.46608781814575195])
# -----Iteration for [ 2.109375 ,  2.12109375 ]
# F:  interval([-0.4055213928222656, 0.17813676595687866])
# -----Iteration for [ 2.109375 ,  2.115234375 ]
# FOUND X = 2.109375   2.115234375
# -----Iteration for [ 2.115234375 ,  2.12109375 ]
# FOUND X = 2.115234375   2.12109375
# -----Iteration for [ 2.12109375 ,  2.1328125 ]
# F:  interval([-0.41842085123062134, 0.16863298416137695])
# -----Iteration for [ 2.12109375 ,  2.126953125 ]
# FOUND X = 2.12109375   2.126953125
# -----Iteration for [ 2.126953125 ,  2.1328125 ]
# FOUND X = 2.126953125   2.1328125
# -----Iteration for [ 2.1328125 ,  2.15625 ]
# F:  interval([-0.733619213104248, 0.450714111328125])
# -----Iteration for [ 2.1328125 ,  2.14453125 ]
# F:  interval([-0.43122053146362305, 0.15923863649368286])
# -----Iteration for [ 2.1328125 ,  2.138671875 ]
# FOUND X = 2.1328125   2.138671875
# -----Iteration for [ 2.138671875 ,  2.14453125 ]
# FOUND X = 2.138671875   2.14453125
# -----Iteration for [ 2.14453125 ,  2.15625 ]
# F:  interval([-0.44391077756881714, 0.14996337890625])
# -----Iteration for [ 2.14453125 ,  2.150390625 ]
# FOUND X = 2.14453125   2.150390625
# -----Iteration for [ 2.150390625 ,  2.15625 ]
# FOUND X = 2.150390625   2.15625
# -----Iteration for [ 2.15625 ,  2.25 ]
# F:  interval([-2.630950927734375, 2.244140625])
# -----Iteration for [ 2.15625 ,  2.203125 ]
# F:  interval([-1.378509521484375, 1.0313301086425781])
# -----Iteration for [ 2.15625 ,  2.1796875 ]
# F:  interval([-0.762176513671875, 0.4358553886413574])
# -----Iteration for [ 2.15625 ,  2.16796875 ]
# F:  interval([-0.45648193359375, 0.14081686735153198])
# -----Iteration for [ 2.15625 ,  2.162109375 ]
# FOUND X = 2.15625   2.162109375
# -----Iteration for [ 2.162109375 ,  2.16796875 ]
# FOUND X = 2.162109375   2.16796875
# -----Iteration for [ 2.16796875 ,  2.1796875 ]
# F:  interval([-0.468924343585968, 0.13180875778198242])
# -----Iteration for [ 2.16796875 ,  2.173828125 ]
# FOUND X = 2.16796875   2.173828125
# -----Iteration for [ 2.173828125 ,  2.1796875 ]
# FOUND X = 2.173828125   2.1796875
# -----Iteration for [ 2.1796875 ,  2.203125 ]
# F:  interval([-0.7902188301086426, 0.4215888977050781])
# -----Iteration for [ 2.1796875 ,  2.19140625 ]
# F:  interval([-0.4812283515930176, 0.12294870615005493])
# -----Iteration for [ 2.1796875 ,  2.185546875 ]
# FOUND X = 2.1796875   2.185546875
# -----Iteration for [ 2.185546875 ,  2.19140625 ]
# FOUND X = 2.185546875   2.19140625
# -----Iteration for [ 2.19140625 ,  2.203125 ]
# F:  interval([-0.49338430166244507, 0.11424636840820312])
# -----Iteration for [ 2.19140625 ,  2.197265625 ]
# FOUND X = 2.19140625   2.197265625
# -----Iteration for [ 2.197265625 ,  2.203125 ]
# FOUND X = 2.197265625   2.203125
# -----Iteration for [ 2.203125 ,  2.25 ]
# F:  interval([-1.4471855163574219, 1.01806640625])
# -----Iteration for [ 2.203125 ,  2.2265625 ]
# F:  interval([-0.8176689147949219, 0.407991886138916])
# -----Iteration for [ 2.203125 ,  2.21484375 ]
# F:  interval([-0.5053825378417969, 0.10571140050888062])
# -----Iteration for [ 2.203125 ,  2.208984375 ]
# FOUND X = 2.203125   2.208984375
# -----Iteration for [ 2.208984375 ,  2.21484375 ]
# FOUND X = 2.208984375   2.21484375
# -----Iteration for [ 2.21484375 ,  2.2265625 ]
# F:  interval([-0.5172134041786194, 0.09735345840454102])
# -----Iteration for [ 2.21484375 ,  2.220703125 ]
# FOUND X = 2.21484375   2.220703125
# -----Iteration for [ 2.220703125 ,  2.2265625 ]
# FOUND X = 2.220703125   2.2265625
# -----Iteration for [ 2.2265625 ,  2.25 ]
# F:  interval([-0.844449520111084, 0.3951416015625])
# -----Iteration for [ 2.2265625 ,  2.23828125 ]
# F:  interval([-0.528867244720459, 0.08918219804763794])
# -----Iteration for [ 2.2265625 ,  2.232421875 ]
# FOUND X = 2.2265625   2.232421875
# -----Iteration for [ 2.232421875 ,  2.23828125 ]
# FOUND X = 2.232421875   2.23828125
# -----Iteration for [ 2.23828125 ,  2.25 ]
# F:  interval([-0.5403344035148621, 0.081207275390625])
# -----Iteration for [ 2.23828125 ,  2.244140625 ]
# FOUND X = 2.23828125   2.244140625
# -----Iteration for [ 2.244140625 ,  2.25 ]
# FOUND X = 2.244140625   2.25
# -----Iteration for [ 2.25 ,  3.0 ]
# F:  interval([-23.859375, 23.625])
# -----Iteration for [ 2.25 ,  2.625 ]
# F:  interval([-11.203125, 10.587890625])
# -----Iteration for [ 2.25 ,  2.4375 ]
# F:  interval([-5.5078125, 4.919677734375])
# -----Iteration for [ 2.25 ,  2.34375 ]
# F:  interval([-2.818359375, 2.280853271484375])
# -----Iteration for [ 2.25 ,  2.296875 ]
# F:  interval([-1.51318359375, 1.0080986022949219])
# -----Iteration for [ 2.25 ,  2.2734375 ]
# F:  interval([-0.8704833984375, 0.383115291595459])
# -----Iteration for [ 2.25 ,  2.26171875 ]
# F:  interval([-0.551605224609375, 0.07343834638595581])
# -----Iteration for [ 2.25 ,  2.255859375 ]
# FOUND X = 2.25   2.255859375
# -----Iteration for [ 2.255859375 ,  2.26171875 ]
# FOUND X = 2.255859375   2.26171875
# -----Iteration for [ 2.26171875 ,  2.2734375 ]
# F:  interval([-0.5626700520515442, 0.06588506698608398])
# -----Iteration for [ 2.26171875 ,  2.267578125 ]
# FOUND X = 2.26171875   2.267578125
# -----Iteration for [ 2.267578125 ,  2.2734375 ]
# FOUND X = 2.267578125   2.2734375
# -----Iteration for [ 2.2734375 ,  2.296875 ]
# F:  interval([-0.895693302154541, 0.3719902038574219])
# -----Iteration for [ 2.2734375 ,  2.28515625 ]
# F:  interval([-0.573519229888916, 0.058557093143463135])
# -----Iteration for [ 2.2734375 ,  2.279296875 ]
# FOUND X = 2.2734375   2.279296875
# -----Iteration for [ 2.279296875 ,  2.28515625 ]
# FOUND X = 2.279296875   2.28515625
# -----Iteration for [ 2.28515625 ,  2.296875 ]
# F:  interval([-0.5841431021690369, 0.051464080810546875])
# -----Iteration for [ 2.28515625 ,  2.291015625 ]
# FOUND X = 2.28515625   2.291015625
# -----Iteration for [ 2.291015625 ,  2.296875 ]
# FOUND X = 2.291015625   2.296875
# -----Iteration for [ 2.296875 ,  2.34375 ]
# F:  interval([-1.5758857727050781, 1.002044677734375])
# -----Iteration for [ 2.296875 ,  2.3203125 ]
# F:  interval([-0.9200019836425781, 0.3618435859680176])
# -----Iteration for [ 2.296875 ,  2.30859375 ]
# F:  interval([-0.5945320129394531, 0.04461568593978882])
# -----Iteration for [ 2.296875 ,  2.302734375 ]
# FOUND X = 2.296875   2.302734375
# -----Iteration for [ 2.302734375 ,  2.30859375 ]
# FOUND X = 2.302734375   2.30859375
# -----Iteration for [ 2.30859375 ,  2.3203125 ]
# F:  interval([-0.6046763062477112, 0.03802156448364258])
# -----Iteration for [ 2.30859375 ,  2.314453125 ]
# FOUND X = 2.30859375   2.314453125
# -----Iteration for [ 2.314453125 ,  2.3203125 ]
# FOUND X = 2.314453125   2.3203125
# -----Iteration for [ 2.3203125 ,  2.34375 ]
# F:  interval([-0.9433321952819824, 0.352752685546875])
# -----Iteration for [ 2.3203125 ,  2.33203125 ]
# F:  interval([-0.6145663261413574, 0.03169137239456177])
# -----Iteration for [ 2.3203125 ,  2.326171875 ]
# FOUND X = 2.3203125   2.326171875
# -----Iteration for [ 2.326171875 ,  2.33203125 ]
# FOUND X = 2.326171875   2.33203125
# -----Iteration for [ 2.33203125 ,  2.34375 ]
# F:  interval([-0.6241924166679382, 0.025634765625])
# -----Iteration for [ 2.33203125 ,  2.337890625 ]
# FOUND X = 2.33203125   2.337890625
# -----Iteration for [ 2.337890625 ,  2.34375 ]
# FOUND X = 2.337890625   2.34375
# -----Iteration for [ 2.34375 ,  2.4375 ]
# F:  interval([-2.992584228515625, 2.335693359375])
# -----Iteration for [ 2.34375 ,  2.390625 ]
# F:  interval([-1.634674072265625, 1.0005226135253906])
# -----Iteration for [ 2.34375 ,  2.3671875 ]
# F:  interval([-0.965606689453125, 0.34479475021362305])
# -----Iteration for [ 2.34375 ,  2.35546875 ]
# F:  interval([-0.633544921875, 0.01986140012741089])
# -----Iteration for [ 2.34375 ,  2.349609375 ]
# FOUND X = 2.34375   2.349609375
# -----Iteration for [ 2.349609375 ,  2.35546875 ]
# FOUND X = 2.349609375   2.35546875
# -----Iteration for [ 2.35546875 ,  2.3671875 ]
# F:  interval([-0.6426141858100891, 0.014380931854248047])
# -----Iteration for [ 2.35546875 ,  2.361328125 ]
# FOUND X = 2.35546875   2.361328125
# -----Iteration for [ 2.361328125 ,  2.3671875 ]
# FOUND X = 2.361328125   2.3671875
# -----Iteration for [ 2.3671875 ,  2.390625 ]
# F:  interval([-0.986748218536377, 0.3380470275878906])
# -----Iteration for [ 2.3671875 ,  2.37890625 ]
# F:  interval([-0.651390552520752, 0.009203016757965088])
# -----Iteration for [ 2.3671875 ,  2.373046875 ]
# FOUND X = 2.3671875   2.373046875
# -----Iteration for [ 2.373046875 ,  2.37890625 ]
# FOUND X = 2.373046875   2.37890625
# -----Iteration for [ 2.37890625 ,  2.390625 ]
# F:  interval([-0.6598643660545349, 0.004337310791015625])
# -----Iteration for [ 2.37890625 ,  2.384765625 ]
# FOUND X = 2.37890625   2.384765625
# -----Iteration for [ 2.384765625 ,  2.390625 ]
# FOUND X = 2.384765625   2.390625
# -----Iteration for [ 2.390625 ,  2.4375 ]
# F:  interval([-1.6889305114746094, 1.004150390625])
# -----Iteration for [ 2.390625 ,  2.4140625 ]
# F:  interval([-1.0066795349121094, 0.33258676528930664])
# -----Iteration for [ 2.390625 ,  2.40234375 ]
# F:  interval([-0.6680259704589844, -0.00020653009414672852])
# -----Iteration for [ 2.40234375 ,  2.4140625 ]
# F:  interval([-0.6758657097816467, -0.004418849945068359])
# -----Iteration for [ 2.4140625 ,  2.4375 ]
# F:  interval([-1.0253233909606934, 0.3284912109375])
# -----Iteration for [ 2.4140625 ,  2.42578125 ]
# F:  interval([-0.6833739280700684, -0.008289992809295654])
# -----Iteration for [ 2.42578125 ,  2.4375 ]
# F:  interval([-0.6905409693717957, -0.011810302734375])
# -----Iteration for [ 2.4375 ,  2.625 ]
# F:  interval([-6.049072265625, 5.314453125])
# -----Iteration for [ 2.4375 ,  2.53125 ]
# F:  interval([-3.148681640625, 2.413604736328125])
# -----Iteration for [ 2.4375 ,  2.484375 ]
# F:  interval([-1.738037109375, 1.0135459899902344])
# -----Iteration for [ 2.4375 ,  2.4609375 ]
# F:  interval([-1.0426025390625, 0.3258376121520996])
# -----Iteration for [ 2.4375 ,  2.44921875 ]
# F:  interval([-0.697357177734375, -0.014970123767852783])
# -----Iteration for [ 2.44921875 ,  2.4609375 ]
# F:  interval([-0.7038128972053528, -0.01775979995727539])
# -----Iteration for [ 2.4609375 ,  2.484375 ]
# F:  interval([-1.0584397315979004, 0.3247032165527344])
# -----Iteration for [ 2.4609375 ,  2.47265625 ]
# F:  interval([-0.7098984718322754, -0.02016967535018921])
# -----Iteration for [ 2.47265625 ,  2.484375 ]
# F:  interval([-0.7156042456626892, -0.022190093994140625])
# -----Iteration for [ 2.484375 ,  2.53125 ]
# F:  interval([-1.7813758850097656, 1.029327392578125])
# -----Iteration for [ 2.484375 ,  2.5078125 ]
# F:  interval([-1.0727577209472656, 0.3251652717590332])
# -----Iteration for [ 2.484375 ,  2.49609375 ]
# F:  interval([-0.7209205627441406, -0.023811399936676025])
# -----Iteration for [ 2.49609375 ,  2.5078125 ]
# F:  interval([-0.725837767124176, -0.025023937225341797])
# -----Iteration for [ 2.5078125 ,  2.53125 ]
# F:  interval([-1.0854792594909668, 0.327301025390625])
# -----Iteration for [ 2.5078125 ,  2.51953125 ]
# F:  interval([-0.7303462028503418, -0.025818049907684326])
# -----Iteration for [ 2.51953125 ,  2.53125 ]
# F:  interval([-0.7344362139701843, -0.02618408203125])
# -----Iteration for [ 2.53125 ,  2.625 ]
# F:  interval([-3.281707763671875, 2.51953125])
# -----Iteration for [ 2.53125 ,  2.578125 ]
# F:  interval([-1.818328857421875, 1.0521125793457031])
# -----Iteration for [ 2.53125 ,  2.5546875 ]
# F:  interval([-1.096527099609375, 0.33118772506713867])
# -----Iteration for [ 2.53125 ,  2.54296875 ]
# F:  interval([-0.73809814453125, -0.026112377643585205])
# -----Iteration for [ 2.54296875 ,  2.5546875 ]
# F:  interval([-0.7413223385810852, -0.025593280792236328])
# -----Iteration for [ 2.5546875 ,  2.578125 ]
# F:  interval([-1.1058239936828613, 0.3369026184082031])
# -----Iteration for [ 2.5546875 ,  2.56640625 ]
# F:  interval([-0.7440991401672363, -0.024617135524749756])
# -----Iteration for [ 2.56640625 ,  2.578125 ]
# F:  interval([-0.7464188933372498, -0.023174285888671875])
# -----Iteration for [ 2.578125 ,  2.625 ]
# F:  interval([-1.8482780456542969, 1.08251953125])
# -----Iteration for [ 2.578125 ,  2.6015625 ]
# F:  interval([-1.1132926940917969, 0.34452295303344727])
# -----Iteration for [ 2.578125 ,  2.58984375 ]
# F:  interval([-0.7482719421386719, -0.021255075931549072])
# -----Iteration for [ 2.58984375 ,  2.6015625 ]
# F:  interval([-0.7496486306190491, -0.018849849700927734])
# -----Iteration for [ 2.6015625 ,  2.625 ]
# F:  interval([-1.1188559532165527, 0.3541259765625])
# -----Iteration for [ 2.6015625 ,  2.61328125 ]
# F:  interval([-0.7505393028259277, -0.015948951244354248])
# -----Iteration for [ 2.61328125 ,  2.625 ]
# F:  interval([-0.7509343028068542, -0.012542724609375])
# -----Iteration for [ 2.625 ,  3.0 ]
# F:  interval([-13.037109375, 12.65625])
# -----Iteration for [ 2.625 ,  2.8125 ]
# F:  interval([-6.498046875, 5.841064453125])
# -----Iteration for [ 2.625 ,  2.71875 ]
# F:  interval([-3.38671875, 2.658416748046875])
# -----Iteration for [ 2.625 ,  2.671875 ]
# F:  interval([-1.87060546875, 1.1211662292480469])
# -----Iteration for [ 2.625 ,  2.6484375 ]
# F:  interval([-1.1224365234375, 0.36578893661499023])
# -----Iteration for [ 2.625 ,  2.63671875 ]
# F:  interval([-0.750823974609375, -0.008621513843536377])
# -----Iteration for [ 2.63671875 ,  2.6484375 ]
# F:  interval([-0.7501986622810364, -0.004175662994384766])
# -----Iteration for [ 2.6484375 ,  2.671875 ]
# F:  interval([-1.1239571571350098, 0.3795890808105469])
# -----Iteration for [ 2.6484375 ,  2.66015625 ]
# F:  interval([-0.7490487098693848, 0.0008044838905334473])
# -----Iteration for [ 2.6484375 ,  2.654296875 ]
# FOUND X = 2.6484375   2.654296875
# -----Iteration for [ 2.654296875 ,  2.66015625 ]
# FOUND X = 2.654296875   2.66015625
# -----Iteration for [ 2.66015625 ,  2.671875 ]
# F:  interval([-0.7473644614219666, 0.006328582763671875])
# -----Iteration for [ 2.66015625 ,  2.666015625 ]
# FOUND X = 2.66015625   2.666015625
# -----Iteration for [ 2.666015625 ,  2.671875 ]
# FOUND X = 2.666015625   2.671875
# -----Iteration for [ 2.671875 ,  2.71875 ]
# F:  interval([-1.8846931457519531, 1.168670654296875])
# -----Iteration for [ 2.671875 ,  2.6953125 ]
# F:  interval([-1.1233406066894531, 0.39560365676879883])
# -----Iteration for [ 2.671875 ,  2.68359375 ]
# F:  interval([-0.7451362609863281, 0.01240628957748413])
# -----Iteration for [ 2.671875 ,  2.677734375 ]
# FOUND X = 2.671875   2.677734375
# -----Iteration for [ 2.677734375 ,  2.68359375 ]
# FOUND X = 2.677734375   2.68359375
# -----Iteration for [ 2.68359375 ,  2.6953125 ]
# F:  interval([-0.7423544526100159, 0.019047260284423828])
# -----Iteration for [ 2.68359375 ,  2.689453125 ]
# FOUND X = 2.68359375   2.689453125
# -----Iteration for [ 2.689453125 ,  2.6953125 ]
# FOUND X = 2.689453125   2.6953125
# -----Iteration for [ 2.6953125 ,  2.71875 ]
# F:  interval([-1.1205096244812012, 0.413909912109375])
# -----Iteration for [ 2.6953125 ,  2.70703125 ]
# F:  interval([-0.7390093803405762, 0.02626115083694458])
# -----Iteration for [ 2.6953125 ,  2.701171875 ]
# FOUND X = 2.6953125   2.701171875
# -----Iteration for [ 2.701171875 ,  2.70703125 ]
# FOUND X = 2.701171875   2.70703125
# -----Iteration for [ 2.70703125 ,  2.71875 ]
# F:  interval([-0.7350913882255554, 0.0340576171875])
# -----Iteration for [ 2.70703125 ,  2.712890625 ]
# FOUND X = 2.70703125   2.712890625
# -----Iteration for [ 2.712890625 ,  2.71875 ]
# FOUND X = 2.712890625   2.71875
# -----Iteration for [ 2.71875 ,  2.8125 ]
# F:  interval([-3.458770751953125, 2.835205078125])
# -----Iteration for [ 2.71875 ,  2.765625 ]
# F:  interval([-1.889923095703125, 1.2256507873535156])
# -----Iteration for [ 2.71875 ,  2.7421875 ]
# F:  interval([-1.115386962890625, 0.4345850944519043])
# -----Iteration for [ 2.71875 ,  2.73046875 ]
# F:  interval([-0.7305908203125, 0.0424463152885437])
# -----Iteration for [ 2.71875 ,  2.724609375 ]
# FOUND X = 2.71875   2.724609375
# -----Iteration for [ 2.724609375 ,  2.73046875 ]
# FOUND X = 2.724609375   2.73046875
# -----Iteration for [ 2.73046875 ,  2.7421875 ]
# F:  interval([-0.7254980206489563, 0.0514369010925293])
# -----Iteration for [ 2.73046875 ,  2.736328125 ]
# FOUND X = 2.73046875   2.736328125
# -----Iteration for [ 2.736328125 ,  2.7421875 ]
# FOUND X = 2.736328125   2.7421875
# -----Iteration for [ 2.7421875 ,  2.765625 ]
# F:  interval([-1.1078953742980957, 0.4577064514160156])
# -----Iteration for [ 2.7421875 ,  2.75390625 ]
# F:  interval([-0.7198033332824707, 0.0610390305519104])
# -----Iteration for [ 2.7421875 ,  2.748046875 ]
# FOUND X = 2.7421875   2.748046875
# -----Iteration for [ 2.748046875 ,  2.75390625 ]
# FOUND X = 2.748046875   2.75390625
# -----Iteration for [ 2.75390625 ,  2.765625 ]
# F:  interval([-0.7134971022605896, 0.07126235961914062])
# -----Iteration for [ 2.75390625 ,  2.759765625 ]
# FOUND X = 2.75390625   2.759765625
# -----Iteration for [ 2.759765625 ,  2.765625 ]
# FOUND X = 2.759765625   2.765625
# -----Iteration for [ 2.765625 ,  2.8125 ]
# F:  interval([-1.8856773376464844, 1.292724609375])
# -----Iteration for [ 2.765625 ,  2.7890625 ]
# F:  interval([-1.0979576110839844, 0.4833512306213379])
# -----Iteration for [ 2.765625 ,  2.77734375 ]
# F:  interval([-0.7065696716308594, 0.08211654424667358])
# -----Iteration for [ 2.765625 ,  2.771484375 ]
# FOUND X = 2.765625   2.771484375
# -----Iteration for [ 2.771484375 ,  2.77734375 ]
# FOUND X = 2.771484375   2.77734375
# -----Iteration for [ 2.77734375 ,  2.7890625 ]
# F:  interval([-0.6990113854408264, 0.09361124038696289])
# -----Iteration for [ 2.77734375 ,  2.783203125 ]
# FOUND X = 2.77734375   2.783203125
# -----Iteration for [ 2.783203125 ,  2.7890625 ]
# FOUND X = 2.783203125   2.7890625
# -----Iteration for [ 2.7890625 ,  2.8125 ]
# F:  interval([-1.085496425628662, 0.5115966796875])
# -----Iteration for [ 2.7890625 ,  2.80078125 ]
# F:  interval([-0.6908125877380371, 0.10575610399246216])
# -----Iteration for [ 2.7890625 ,  2.794921875 ]
# FOUND X = 2.7890625   2.794921875
# -----Iteration for [ 2.794921875 ,  2.80078125 ]
# FOUND X = 2.794921875   2.80078125
# -----Iteration for [ 2.80078125 ,  2.8125 ]
# F:  interval([-0.6819636225700378, 0.118560791015625])
# -----Iteration for [ 2.80078125 ,  2.806640625 ]
# FOUND X = 2.80078125   2.806640625
# -----Iteration for [ 2.806640625 ,  2.8125 ]
# FOUND X = 2.806640625   2.8125
# -----Iteration for [ 2.8125 ,  3.0 ]
# F:  interval([-6.815185546875, 6.5390625])
# -----Iteration for [ 2.8125 ,  2.90625 ]
# F:  interval([-3.492919921875, 3.054840087890625])
# -----Iteration for [ 2.8125 ,  2.859375 ]
# F:  interval([-1.871337890625, 1.3705101013183594])
# -----Iteration for [ 2.8125 ,  2.8359375 ]
# F:  interval([-1.0704345703125, 0.5425200462341309])
# ...
# F:  interval([-0.6010050773620605, 0.2274797558784485])
# -----Iteration for [ 2.8828125 ,  2.888671875 ]
# FOUND X = 2.8828125   2.888671875
# -----Iteration for [ 2.888671875 ,  2.89453125 ]
# FOUND X = 2.888671875   2.89453125
# -----Iteration for [ 2.89453125 ,  2.90625 ]
# F:  interval([-0.5866071581840515, 0.24591064453125])
# -----Iteration for [ 2.89453125 ,  2.900390625 ]
# FOUND X = 2.89453125   2.900390625
# -----Iteration for [ 2.900390625 ,  2.90625 ]
# FOUND X = 2.900390625   2.90625
# -----Iteration for [ 2.90625 ,  3.0 ]
# F:  interval([-3.484222412109375, 3.322265625])
# -----Iteration for [ 2.90625 ,  2.953125 ]
# F:  interval([-1.809906005859375, 1.5606880187988281])
# -----Iteration for [ 2.90625 ,  2.9296875 ]
# F:  interval([-0.982635498046875, 0.6945376396179199])
# -----Iteration for [ 2.90625 ,  2.91796875 ]
# F:  interval([-0.57147216796875, 0.2650882601737976])
# -----Iteration for [ 2.90625 ,  2.912109375 ]
# FOUND X = 2.90625   2.912109375
# -----Iteration for [ 2.912109375 ,  2.91796875 ]
# FOUND X = 2.912109375   2.91796875
# -----Iteration for [ 2.91796875 ,  2.9296875 ]
# F:  interval([-0.5555904507637024, 0.2850222587585449])
# -----Iteration for [ 2.91796875 ,  2.923828125 ]
# FOUND X = 2.91796875   2.923828125
# -----Iteration for [ 2.923828125 ,  2.9296875 ]
# FOUND X = 2.923828125   2.9296875
# -----Iteration for [ 2.9296875 ,  2.953125 ]
# F:  interval([-0.9534115791320801, 0.7400093078613281])
# -----Iteration for [ 2.9296875 ,  2.94140625 ]
# F:  interval([-0.5389523506164551, 0.30572229623794556])
# -----Iteration for [ 2.9296875 ,  2.935546875 ]
# FOUND X = 2.9296875   2.935546875
# -----Iteration for [ 2.935546875 ,  2.94140625 ]
# FOUND X = 2.935546875   2.94140625
# -----Iteration for [ 2.94140625 ,  2.953125 ]
# F:  interval([-0.5215482115745544, 0.3271980285644531])
# -----Iteration for [ 2.94140625 ,  2.947265625 ]
# FOUND X = 2.94140625   2.947265625
# -----Iteration for [ 2.947265625 ,  2.953125 ]
# FOUND X = 2.947265625   2.953125
# -----Iteration for [ 2.953125 ,  3.0 ]
# F:  interval([-1.7615776062011719, 1.67431640625])
# -----Iteration for [ 2.953125 ,  2.9765625 ]
# F:  interval([-0.9211235046386719, 0.7886223793029785])
# -----Iteration for [ 2.953125 ,  2.96484375 ]
# F:  interval([-0.5033683776855469, 0.34945911169052124])
# -----Iteration for [ 2.953125 ,  2.958984375 ]
# FOUND X = 2.953125   2.958984375
# -----Iteration for [ 2.958984375 ,  2.96484375 ]
# FOUND X = 2.958984375   2.96484375
# -----Iteration for [ 2.96484375 ,  2.9765625 ]
# F:  interval([-0.48440319299697876, 0.3725152015686035])
# -----Iteration for [ 2.96484375 ,  2.970703125 ]
# FOUND X = 2.96484375   2.970703125
# -----Iteration for [ 2.970703125 ,  2.9765625 ]
# FOUND X = 2.970703125   2.9765625
# -----Iteration for [ 2.9765625 ,  3.0 ]
# F:  interval([-0.8856940269470215, 0.8404541015625])
# -----Iteration for [ 2.9765625 ,  2.98828125 ]
# F:  interval([-0.4646430015563965, 0.39637595415115356])
# -----Iteration for [ 2.9765625 ,  2.982421875 ]
# FOUND X = 2.9765625   2.982421875
# -----Iteration for [ 2.982421875 ,  2.98828125 ]
# FOUND X = 2.982421875   2.98828125
# -----Iteration for [ 2.98828125 ,  3.0 ]
# F:  interval([-0.44407814741134644, 0.421051025390625])
# -----Iteration for [ 2.98828125 ,  2.994140625 ]
# FOUND X = 2.98828125   2.994140625
# -----Iteration for [ 2.994140625 ,  3.0 ]
# FOUND X = 2.994140625   3.0
# -----Iteration for [ 3.0 ,  6 ]
# F:  interval([-162.0, 222.0])
# -----Iteration for [ 3.0 ,  4.5 ]
# F:  interval([-67.5, 80.625])
# -----Iteration for [ 3.0 ,  3.75 ]
# F:  interval([-30.375, 33.984375])
# -----Iteration for [ 3.0 ,  3.375 ]
# F:  interval([-14.34375, 15.568359375])
# -----Iteration for [ 3.0 ,  3.1875 ]
# F:  interval([-6.9609375, 7.447998046875])
# -----Iteration for [ 3.0 ,  3.09375 ]
# F:  interval([-3.427734375, 3.642425537109375])
# -----Iteration for [ 3.0 ,  3.046875 ]
# F:  interval([-1.70068359375, 1.8011283874511719])
# -----Iteration for [ 3.0 ,  3.0234375 ]
# F:  interval([-0.8470458984375, 0.8955817222595215])
# -----Iteration for [ 3.0 ,  3.01171875 ]
# F:  interval([-0.422698974609375, 0.44655007123947144])
# -----Iteration for [ 3.0 ,  3.005859375 ]
# FOUND X = 3.0   3.005859375
# -----Iteration for [ 3.005859375 ,  3.01171875 ]
# FOUND X = 3.005859375   3.01171875
# -----Iteration for [ 3.01171875 ,  3.0234375 ]
# F:  interval([-0.40049582719802856, 0.4728827476501465])
# -----Iteration for [ 3.01171875 ,  3.017578125 ]
# FOUND X = 3.01171875   3.017578125
# -----Iteration for [ 3.017578125 ,  3.0234375 ]
# FOUND X = 3.017578125   3.0234375
# -----Iteration for [ 3.0234375 ,  3.046875 ]
# F:  interval([-0.8051018714904785, 0.9540824890136719])
# -----Iteration for [ 3.0234375 ,  3.03515625 ]
# F:  interval([-0.3774590492248535, 0.5000587105751038])
# -----Iteration for [ 3.0234375 ,  3.029296875 ]
# FOUND X = 3.0234375   3.029296875
# -----Iteration for [ 3.029296875 ,  3.03515625 ]
# FOUND X = 3.029296875   3.03515625
# -----Iteration for [ 3.03515625 ,  3.046875 ]
# F:  interval([-0.35357898473739624, 0.5280876159667969])
# -----Iteration for [ 3.03515625 ,  3.041015625 ]
# FOUND X = 3.03515625   3.041015625
# -----Iteration for [ 3.041015625 ,  3.046875 ]
# FOUND X = 3.041015625   3.046875
# -----Iteration for [ 3.046875 ,  3.09375 ]
# F:  interval([-1.6266059875488281, 1.941741943359375])
# -----Iteration for [ 3.046875 ,  3.0703125 ]
# F:  interval([-0.7597846984863281, 1.01603364944458])
# -----Iteration for [ 3.046875 ,  3.05859375 ]
# F:  interval([-0.3288459777832031, 0.5569791197776794])
# -----Iteration for [ 3.046875 ,  3.052734375 ]
# FOUND X = 3.046875   3.052734375
# -----Iteration for [ 3.052734375 ,  3.05859375 ]
# FOUND X = 3.052734375   3.05859375
# -----Iteration for [ 3.05859375 ,  3.0703125 ]
# F:  interval([-0.30325037240982056, 0.5867428779602051])
# -----Iteration for [ 3.05859375 ,  3.064453125 ]
# FOUND X = 3.05859375   3.064453125
# -----Iteration for [ 3.064453125 ,  3.0703125 ]
# FOUND X = 3.064453125   3.0703125
# -----Iteration for [ 3.0703125 ,  3.09375 ]
# F:  interval([-0.7110171318054199, 1.081512451171875])
# -----Iteration for [ 3.0703125 ,  3.08203125 ]
# F:  interval([-0.2767825126647949, 0.6173885464668274])
# -----Iteration for [ 3.0703125 ,  3.076171875 ]
# FOUND X = 3.0703125   3.076171875
# -----Iteration for [ 3.076171875 ,  3.08203125 ]
# FOUND X = 3.076171875   3.08203125
# -----Iteration for [ 3.08203125 ,  3.09375 ]
# F:  interval([-0.2494327425956726, 0.64892578125])
# -----Iteration for [ 3.08203125 ,  3.087890625 ]
# FOUND X = 3.08203125   3.087890625
# -----Iteration for [ 3.087890625 ,  3.09375 ]
# FOUND X = 3.087890625   3.09375
# -----Iteration for [ 3.09375 ,  3.1875 ]
# F:  interval([-3.318511962890625, 4.020263671875])
# -----Iteration for [ 3.09375 ,  3.140625 ]
# F:  interval([-1.538726806640625, 2.0967750549316406])
# -----Iteration for [ 3.09375 ,  3.1171875 ]
# F:  interval([-0.658721923828125, 1.1505961418151855])
# -----Iteration for [ 3.09375 ,  3.10546875 ]
# F:  interval([-0.22119140625, 0.6813642382621765])
# -----Iteration for [ 3.09375 ,  3.099609375 ]
# FOUND X = 3.09375   3.099609375
# -----Iteration for [ 3.099609375 ,  3.10546875 ]
# FOUND X = 3.099609375   3.10546875
# -----Iteration for [ 3.10546875 ,  3.1171875 ]
# F:  interval([-0.1920488476753235, 0.7147135734558105])
# -----Iteration for [ 3.10546875 ,  3.111328125 ]
# FOUND X = 3.10546875   3.111328125
# -----Iteration for [ 3.111328125 ,  3.1171875 ]
# FOUND X = 3.111328125   3.1171875
# -----Iteration for [ 3.1171875 ,  3.140625 ]
# F:  interval([-0.6028218269348145, 1.2233619689941406])
# -----Iteration for [ 3.1171875 ,  3.12890625 ]
# F:  interval([-0.16199541091918945, 0.7489834427833557])
# -----Iteration for [ 3.1171875 ,  3.123046875 ]
# FOUND X = 3.1171875   3.123046875
# -----Iteration for [ 3.123046875 ,  3.12890625 ]
# FOUND X = 3.123046875   3.12890625
# -----Iteration for [ 3.12890625 ,  3.140625 ]
# F:  interval([-0.1310214400291443, 0.7841835021972656])
# -----Iteration for [ 3.12890625 ,  3.134765625 ]
# FOUND X = 3.12890625   3.134765625
# -----Iteration for [ 3.134765625 ,  3.140625 ]
# FOUND X = 3.134765625   3.140625
# -----Iteration for [ 3.140625 ,  3.1875 ]
# F:  interval([-1.4364280700683594, 2.266845703125])
# -----Iteration for [ 3.140625 ,  3.1640625 ]
# F:  interval([-0.5432395935058594, 1.2998871803283691])
# -----Iteration for [ 3.140625 ,  3.15234375 ]
# F:  interval([-0.09911727905273438, 0.8203234076499939])
# -----Iteration for [ 3.140625 ,  3.146484375 ]
# FOUND X = 3.140625   3.146484375
# -----Iteration for [ 3.146484375 ,  3.15234375 ]
# FOUND X = 3.146484375   3.15234375
# -----Iteration for [ 3.15234375 ,  3.1640625 ]
# F:  interval([-0.0662732720375061, 0.8574128150939941])
# -----Iteration for [ 3.15234375 ,  3.158203125 ]
# FOUND X = 3.15234375   3.158203125
# -----Iteration for [ 3.158203125 ,  3.1640625 ]
# FOUND X = 3.158203125   3.1640625
# -----Iteration for [ 3.1640625 ,  3.1875 ]
# F:  interval([-0.47989797592163086, 1.3802490234375])
# -----Iteration for [ 3.1640625 ,  3.17578125 ]
# F:  interval([-0.03247976303100586, 0.89546138048172])
# -----Iteration for [ 3.1640625 ,  3.169921875 ]
# FOUND X = 3.1640625   3.169921875
# -----Iteration for [ 3.169921875 ,  3.17578125 ]
# FOUND X = 3.169921875   3.17578125
# -----Iteration for [ 3.17578125 ,  3.1875 ]
# F:  interval([0.0022729039192199707, 0.934478759765625])
# -----Iteration for [ 3.1875 ,  3.375 ]
# F:  interval([-6.895751953125, 8.607421875])
# -----Iteration for [ 3.1875 ,  3.28125 ]
# F:  interval([-3.151611328125, 4.460723876953125])
# -----Iteration for [ 3.1875 ,  3.234375 ]
# F:  interval([-1.319091796875, 2.4525718688964844])
# -----Iteration for [ 3.1875 ,  3.2109375 ]
# F:  interval([-0.4127197265625, 1.464524745941162])
# -----Iteration for [ 3.1875 ,  3.19921875 ]
# F:  interval([0.037994384765625, 0.9744746088981628])
# -----Iteration for [ 3.19921875 ,  3.2109375 ]
# F:  interval([0.07469433546066284, 1.015458583831787])
# -----Iteration for [ 3.2109375 ,  3.234375 ]
# F:  interval([-0.3416275978088379, 1.5527915954589844])
# -----Iteration for [ 3.2109375 ,  3.22265625 ]
# F:  interval([0.11238241195678711, 1.0574403405189514])
# -----Iteration for [ 3.22265625 ,  3.234375 ]
# F:  interval([0.15106827020645142, 1.1004295349121094])
# -----Iteration for [ 3.234375 ,  3.28125 ]
# F:  interval([-1.1861000061035156, 2.654571533203125])
# -----Iteration for [ 3.234375 ,  3.2578125 ]
# F:  interval([-0.2665443420410156, 1.6451268196105957])
# -----Iteration for [ 3.234375 ,  3.24609375 ]
# F:  interval([0.19076156616210938, 1.1444358229637146])
# -----Iteration for [ 3.24609375 ,  3.2578125 ]
# F:  interval([0.2314719557762146, 1.1894688606262207])
# -----Iteration for [ 3.2578125 ,  3.28125 ]
# F:  interval([-0.1873927116394043, 1.741607666015625])
# -----Iteration for [ 3.2578125 ,  3.26953125 ]
# F:  interval([0.2732090950012207, 1.2355383038520813])
# -----Iteration for [ 3.26953125 ,  3.28125 ]
# F:  interval([0.3159826397895813, 1.28265380859375])
# -----Iteration for [ 3.28125 ,  3.375 ]
# F:  interval([-2.922088623046875, 4.96875])
# -----Iteration for [ 3.28125 ,  3.328125 ]
# F:  interval([-1.036834716796875, 2.873462677001953])
# -----Iteration for [ 3.28125 ,  3.3046875 ]
# F:  interval([-0.104095458984375, 1.8423113822937012])
# -----Iteration for [ 3.28125 ,  3.29296875 ]
# F:  interval([0.35980224609375, 1.3308250308036804])
# -----Iteration for [ 3.29296875 ,  3.3046875 ]
# F:  interval([0.4046775698661804, 1.3800616264343262])
# -----Iteration for [ 3.3046875 ,  3.328125 ]
# F:  interval([-0.016575336456298828, 1.9473152160644531])
# -----Iteration for [ 3.3046875 ,  3.31640625 ]
# F:  interval([0.45061826705932617, 1.4303732514381409])
# -----Iteration for [ 3.31640625 ,  3.328125 ]
# F:  interval([0.49763399362564087, 1.4817695617675781])
# -----Iteration for [ 3.328125 ,  3.375 ]
# F:  interval([-0.8706779479980469, 3.10986328125])
# -----Iteration for [ 3.328125 ,  3.3515625 ]
# F:  interval([0.07524490356445312, 2.0566964149475098])
# -----Iteration for [ 3.3515625 ,  3.375 ]
# F:  interval([0.17144250869750977, 2.1705322265625])
# -----Iteration for [ 3.375 ,  3.75 ]
# F:  interval([-14.806640625, 19.640625])
# -----Iteration for [ 3.375 ,  3.5625 ]
# F:  interval([-6.580078125, 10.056884765625])
# -----Iteration for [ 3.375 ,  3.46875 ]
# F:  interval([-2.625, 5.549285888671875])
# -----Iteration for [ 3.375 ,  3.421875 ]
# F:  interval([-0.68701171875, 3.364391326904297])
# -----Iteration for [ 3.375 ,  3.3984375 ]
# F:  interval([0.2720947265625, 2.2888998985290527])
# -----Iteration for [ 3.3984375 ,  3.421875 ]
# F:  interval([0.37727880477905273, 2.411876678466797])
# -----Iteration for [ 3.421875 ,  3.46875 ]
# F:  interval([-0.4852180480957031, 3.637664794921875])
# -----Iteration for [ 3.421875 ,  3.4453125 ]
# F:  interval([0.4870719909667969, 2.5395398139953613])
# -----Iteration for [ 3.4453125 ,  3.46875 ]
# F:  interval([0.6015515327453613, 2.671966552734375])
# -----Iteration for [ 3.46875 ,  3.5625 ]
# F:  interval([-2.255401611328125, 6.207275390625])
# -----Iteration for [ 3.46875 ,  3.515625 ]
# F:  interval([-0.264678955078125, 3.9303016662597656])
# -----Iteration for [ 3.46875 ,  3.4921875 ]
# F:  interval([0.720794677734375, 2.809234142303467])
# -----Iteration for [ 3.4921875 ,  3.515625 ]
# F:  interval([0.8448786735534668, 2.9514198303222656])
# -----Iteration for [ 3.515625 ,  3.5625 ]
# F:  interval([-0.024776458740234375, 4.242919921875])
# -----Iteration for [ 3.515625 ,  3.5390625 ]
# F:  interval([0.9738807678222656, 3.0986008644104004])
# -----Iteration for [ 3.5390625 ,  3.5625 ]
# F:  interval([1.1078782081604004, 3.2508544921875])
# -----Iteration for [ 3.5625 ,  3.75 ]
# F:  interval([-5.974365234375, 11.8359375])
# -----Iteration for [ 3.5625 ,  3.65625 ]
# F:  interval([-1.808349609375, 6.947662353515625])
# -----Iteration for [ 3.5625 ,  3.609375 ]
# F:  interval([0.235107421875, 4.576137542724609])
# -----Iteration for [ 3.609375 ,  3.65625 ]
# F:  interval([0.5155906677246094, 4.930572509765625])
# -----Iteration for [ 3.65625 ,  3.75 ]
# F:  interval([-1.278900146484375, 7.775390625])
# -----Iteration for [ 3.65625 ,  3.703125 ]
# F:  interval([0.817291259765625, 5.306842803955078])
# -----Iteration for [ 3.703125 ,  3.75 ]
# F:  interval([1.1408271789550781, 5.70556640625])
# -----Iteration for [ 3.75 ,  4.5 ]
# F:  interval([-33.515625, 50.25])
# -----Iteration for [ 3.75 ,  4.125 ]
# F:  interval([-14.109375, 25.189453125])
# -----Iteration for [ 3.75 ,  3.9375 ]
# F:  interval([-5.0390625, 13.984130859375])
# -----Iteration for [ 3.75 ,  3.84375 ]
# F:  interval([-0.662109375, 8.695404052734375])
# -----Iteration for [ 3.75 ,  3.796875 ]
# F:  interval([1.48681640625, 6.127361297607422])
# -----Iteration for [ 3.796875 ,  3.84375 ]
# F:  interval([1.8558769226074219, 6.572845458984375])
# -----Iteration for [ 3.84375 ,  3.9375 ]
# F:  interval([0.046966552734375, 9.712646484375])
# -----Iteration for [ 3.9375 ,  4.125 ]
# F:  interval([-3.734619140625, 16.541015625])
# -----Iteration for [ 3.9375 ,  4.03125 ]
# F:  interval([0.853271484375, 10.832061767578125])
# -----Iteration for [ 4.03125 ,  4.125 ]
# F:  interval([1.761749267578125, 12.05859375])
# -----Iteration for [ 4.125 ,  4.5 ]
# F:  interval([-11.935546875, 32.53125])
# -----Iteration for [ 4.125 ,  4.3125 ]
# F:  interval([-2.021484375, 19.546142578125])
# -----Iteration for [ 4.125 ,  4.21875 ]
# F:  interval([2.77734375, 13.397186279296875])
# -----Iteration for [ 4.21875 ,  4.3125 ]
# F:  interval([3.904998779296875, 14.852783203125])
# -----Iteration for [ 4.3125 ,  4.5 ]
# F:  interval([0.139892578125, 23.0390625])
# -----Iteration for [ 4.5 ,  6 ]
# F:  interval([-81.375, 154.5])
# -----Iteration for [ 4.5 ,  5.25 ]
# F:  interval([-30.75, 74.953125])
# -----Iteration for [ 4.5 ,  4.875 ]
# F:  interval([-7.96875, 41.982421875])
# -----Iteration for [ 4.5 ,  4.6875 ]
# F:  interval([2.7890625, 27.059326171875])
# -----Iteration for [ 4.6875 ,  4.875 ]
# F:  interval([5.965576171875, 31.646484375])
# -----Iteration for [ 4.875 ,  5.25 ]
# F:  interval([-1.892578125, 53.859375])
# -----Iteration for [ 4.875 ,  5.0625 ]
# F:  interval([9.708984375, 36.840087890625])
# -----Iteration for [ 5.0625 ,  5.25 ]
# F:  interval([14.058837890625, 42.6796875])
# -----Iteration for [ 5.25 ,  6 ]
# F:  interval([-19.546875, 110.625])
# -----Iteration for [ 5.25 ,  5.625 ]
# F:  interval([6.609375, 68.478515625])
# -----Iteration for [ 5.625 ,  6 ]
# F:  interval([17.853515625, 86.15625])

# %%
def liniar_mura(start, end, e):
  print('-----Iteration for [', start, ', ', end, '] ----------')
  check = end - start
  if check < e:
    print('FOUND X =', start, ' ', end)
    return
  X0 = interval([start, end])
  mid = (start+end)/2;
  # function
  f = mid**3 - 3*mid + 2
  if f == 0.0:
    liniar_mura(start, mid, e)
    liniar_mura(mid, end, e)
    return
  print('function value:', f);
  print('middle: ',  end-start)
  # derivative
  f_derivative = 3*X0*X0 - 3
  
  # print('function deritive: ', f_derivative);

  U = mid - f/f_derivative
  # print('U: ', U);
  
  X1 = U & X0
  [liniar_mura(x.inf, x.sup, e) for x in X1]
  
print("Лінійний алгоритм Мура");
print("x^3 - 6*x^2 + 11*x - 6 = 0");
print("1, 2, 3");
print("[0; 6]");
print("------------");
x1 = 1;
x2 = 2;
x3 = 3;
e = 10**(-6)

a = -2;
b = 1;

liniar_mura(a, b, e)
# Out:
# Лінійний алгоритм Мура
# x^3 - 6*x^2 + 11*x - 6 = 0
# 1, 2, 3
# [0; 6]
# ------------
# -----Iteration for [ -2 ,  1 ] ----------
# function value: 3.375
# middle:  3
# -----Iteration for [ -2.0 ,  -0.8749999999999999 ] ----------
# function value: 3.342041015625
# middle:  1.125
# -----Iteration for [ -2.0 ,  -1.8088378906249998 ] ----------
# function value: 0.8062882675712899
# middle:  0.19116210937500022
# -----Iteration for [ -2.0 ,  -1.9940065305981987 ] ----------
# function value: 0.026916756706832246
# middle:  0.0059934694018013435
# -----Iteration for [ -2.0 ,  -1.9999940160443028 ] ----------
# function value: 2.692774692558686e-05
# middle:  5.983955697175247e-06
# -----Iteration for [ -2.0 ,  -1.9999999999940319 ] ----------
# FOUND X = -2.0   -1.9999999999940319
# -----Iteration for [ -0.12500000000000006 ,  1.0 ] ----------
# function value: 0.771240234375
# middle:  1.125
# -----Iteration for [ 0.6660156249999999 ,  1.0 ] ----------
# function value: 0.07900236267596483
# middle:  0.3339843750000001
# -----Iteration for [ 0.880335316987837 ,  1.0 ] ----------
# function value: 0.01052553292706171
# middle:  0.11966468301216304
# -----Iteration for [ 0.9557603663333863 ,  1.0 ] ----------
# function value: 0.0014570359669541233
# middle:  0.044239633666613654
# -----Iteration for [ 0.9834935297144154 ,  1.0 ] ----------
# function value: 0.00020378549450694727
# middle:  0.016506470285584607
# -----Iteration for [ 0.9938215207671012 ,  1.0 ] ----------
# function value: 2.8600722369764853e-05
# middle:  0.006178479232898826
# -----Iteration for [ 0.9976846657834314 ,  1.0 ] ----------
# function value: 4.019027903368055e-06
# middle:  0.0023153342165685986
# -----Iteration for [ 0.9991319732931965 ,  1.0 ] ----------
# function value: 5.650210188612448e-07
# middle:  0.0008680267068035263
# -----Iteration for [ 0.9996745213932013 ,  1.0 ] ----------
# function value: 7.944793267711248e-08
# middle:  0.00032547860679865703
# -----Iteration for [ 0.9998779499372158 ,  1.0 ] ----------
# function value: 1.117193626498647e-08
# middle:  0.00012205006278420694
# -----Iteration for [ 0.9999542318473829 ,  1.0 ] ----------
# function value: 1.5710308609584445e-09
# middle:  4.576815261714273e-05
# -----Iteration for [ 0.9999828370300485 ,  1.0 ] ----------
# function value: 2.2092483398239438e-10
# middle:  1.7162969951467488e-05
# -----Iteration for [ 0.9999935638967238 ,  1.0 ] ----------
# function value: 3.106759294269068e-11
# middle:  6.4361032762194625e-06
# -----Iteration for [ 0.9999975864644794 ,  1.0 ] ----------
# function value: 4.368727601899991e-12
# middle:  2.4135355205512354e-06
# -----Iteration for [ 0.9999990949150364 ,  1.0 ] ----------
# FOUND X = 0.9999990949150364   1.0

# %%
def liniar_hansen(start, end, e):
  print('-----Iteration for [', start, ', ', end, '] ----------')
  check = end - start
  X0 = interval([start, end])
  if check < e:
    print('FOUND X =', start, ' ', end)
    return;
  
  mid = (start+end)/2;
  # print('middle: ',  mid)
  # function
  #f = mid*mid + mid - 2
  #f_derivative = 2*mid + 1
  f = mid**3 - 6*mid**2 + 11*mid - 6
  #fX0 = X0*X0*X0 - 6*X0*X0 + 11*X0 - 6
  
  print('function value:', f);
  # derivative
  F_derivative = 3*X0*X0 - 12*X0 + 11
  #F_derivative = 2 * X0 + 1
    
  temp = [x for x in F_derivative]
  # print("Temp: ", temp)
  c = temp[0].inf
  d = temp[0].sup
  print("c: ", c)
  print("d: ", d)
  
  if 0 not in F_derivative:
    print('Stop. F_derivative does not have 0')
    print("X0: ", X0)
    return;

  
  if f == 0.0:
    print('FOUND X =', start, ' ', end)
    liniar_hansen(start, mid, e)
    liniar_hansen(mid, end, e)
    return
  elif f > 0.0:
    if c == 0.0:
      q = mid - f/d
      U = interval([-math.inf, q])
    elif d == 0.0:
      p = mid - f/c
      U = interval([p, math.inf])
    elif c < 0.0 and 0.0 < d:
      q = mid - f/d
      p = mid - f/c
      U = interval([-math.inf, q]) | interval([p, math.inf])
  elif f < 0.0:
    if c == 0.0:
      q = mid - f/d
      U = interval([q, math.inf])
    elif d == 0.0:
      p = mid - f/c
      U = interval([-math.inf, p])
    elif c < 0.0 and 0.0 < d:
      q = mid - f/d
      p = mid - f/c
      U = interval([-math.inf, p]) | interval([q, math.inf])
        
  X1 = U & X0
  
  print('X0: ', X0);
  print('U: ', U);
  print('X1: ', X1);

  result = list(map(lambda x: liniar_hansen(x.inf, x.sup, e), X1))
  # print("result: ", result)
  return


print("Лінійний алгоритм Хансена");
print("x^3 - 6*x^2 + 11*x - 6 = 0");
print("1, 2, 3");
print("[0; 4]");
print("------------");
x1 = 1;
x2 = 2;
x3 = 3;
e = 10**(-2)

a = 0;
b = 4;

liniar_hansen(a, b, e)
# Out:
# Лінійний алгоритм Хансена
# x^3 - 6*x^2 + 11*x - 6 = 0
# 1, 2, 3
# [0; 4]
# ------------
# -----Iteration for [ 0 ,  4 ] ----------
# function value: 0.0
# c:  -37.0
# d:  59.0
# FOUND X = 0   4
# -----Iteration for [ 0 ,  2.0 ] ----------
# function value: 0.0
# c:  -13.0
# d:  23.0
# FOUND X = 0   2.0
# -----Iteration for [ 0 ,  1.0 ] ----------
# function value: -1.875
# c:  -1.0
# d:  14.0
# X0:  interval([0.0, 1.0])
# U:  interval([-inf, -1.375], [0.6339285714285714, inf])
# X1:  interval([0.6339285714285714, 1.0])
# -----Iteration for [ 0.6339285714285714 ,  1.0 ] ----------
# function value: -0.47270972249111765
# c:  0.2055963010204067
# d:  6.392857142857143
# Stop. F_derivative does not have 0
# X0:  interval([0.6339285714285714, 1.0])
# -----Iteration for [ 1.0 ,  2.0 ] ----------
# function value: 0.375
# c:  -10.0
# d:  11.0
# X0:  interval([1.0, 2.0])
# U:  interval([-inf, 1.4659090909090908], [1.5375, inf])
# X1:  interval([1.0, 1.4659090909090908], [1.5375, 2.0])
# -----Iteration for [ 1.0 ,  1.4659090909090908 ] ----------
# function value: 0.31574756556395656
# c:  -3.59090909090909
# d:  5.446668388429752
# X0:  interval([1.0, 1.4659090909090908])
# U:  interval([-inf, 1.1749837745086416], [1.3208842472571662, inf])
# X1:  interval([1.0, 1.1749837745086416], [1.3208842472571662, 1.4659090909090908])
# -----Iteration for [ 1.0 ,  1.1749837745086416 ] ----------
# function value: 0.15268901905532317
# c:  -0.09980529410369954
# d:  3.141760611075723
# X0:  interval([1.0, 1.1749837745086416])
# U:  interval([-inf, 1.038892061246876], [2.617360822830789, inf])
# X1:  interval([1.0, 1.038892061246876])
# -----Iteration for [ 1.0 ,  1.038892061246876 ] ----------
# function value: 0.0377649704055214
# c:  1.5332952650374878
# d:  2.2378901447653483
# Stop. F_derivative does not have 0
# X0:  interval([1.0, 1.038892061246876])
# -----Iteration for [ 1.3208842472571662 ,  1.4659090909090908 ] ----------
# function value: 0.3833929584325908
# c:  -1.356703506952698
# d:  1.5960574213437582
# X0:  interval([1.3208842472571662, 1.4659090909090908])
# U:  interval([-inf, 1.1531841596172703], [1.6759882275686908, inf])
# X1:  interval()
# -----Iteration for [ 1.5375 ,  2.0 ] ----------
# function value: 0.21888354492187645
# c:  -5.908281250000002
# d:  4.550000000000001
# X0:  interval([1.5375, 2.0])
# U:  interval([-inf, 1.7206437263907963], [1.8057969068177613, inf])
# X1:  interval([1.5375, 1.7206437263907963], [1.8057969068177613, 2.0])
# -----Iteration for [ 1.5375 ,  1.7206437263907963 ] ----------
# function value: 0.3198929940233235
# c:  -2.556005966689556
# d:  1.4318444995040185
# X0:  interval([1.5375, 1.7206437263907963])
# U:  interval([-inf, 1.4056586405066689], [1.7542253245692139, inf])
# X1:  interval()
# -----Iteration for [ 1.8057969068177613 ,  2.0 ] ----------
# function value: 0.09618600423373991
# c:  -3.217292593982217
# d:  1.3304371181868646
# X0:  interval([1.8057969068177613, 2.0])
# U:  interval([-inf, 1.8306019104765672], [1.9327950206075404, inf])
# X1:  interval([1.8057969068177613, 1.8306019104765672], [1.9327950206075404, 2.0])
# -----Iteration for [ 1.8057969068177613 ,  1.8306019104765672 ] ----------
# function value: 0.1757918172858144
# c:  -1.1845155197010246
# d:  -0.6162528178917608
# Stop. F_derivative does not have 0
# X0:  interval([1.8057969068177613, 1.8306019104765672])
# -----Iteration for [ 1.9327950206075404 ,  2.0 ] ----------
# function value: 0.033564548207301925
# c:  -1.7929102249440945
# d:  -0.19354024729048191
# Stop. F_derivative does not have 0
# X0:  interval([1.9327950206075404, 2.0])
# -----Iteration for [ 2.0 ,  4 ] ----------
# function value: 0.0
# c:  -25.0
# d:  35.0
# FOUND X = 2.0   4
# -----Iteration for [ 2.0 ,  3.0 ] ----------
# function value: -0.375
# c:  -13.0
# d:  14.0
# X0:  interval([2.0, 3.0])
# U:  interval([-inf, 2.4711538461538463], [2.5267857142857144, inf])
# X1:  interval([2.0, 2.4711538461538463], [2.5267857142857144, 3.0])
# -----Iteration for [ 2.0 ,  2.4711538461538463 ] ----------
# function value: -0.222503231501765
# c:  -6.653846153846157
# d:  5.319803994082843
# X0:  interval([2.0, 2.4711538461538463])
# U:  interval([-inf, 2.202137131059317], [2.2774023797571417, inf])
# X1:  interval([2.0, 2.202137131059317], [2.2774023797571417, 2.4711538461538463])
# -----Iteration for [ 2.0 ,  2.202137131059317 ] ----------
# function value: -0.10003616479395916
# c:  -3.425645572711808
# d:  1.548223831970482
# X0:  interval([2.0, 2.202137131059317])
# U:  interval([-inf, 2.071866430436982], [2.165682068259841, inf])
# X1:  interval([2.0, 2.071866430436982], [2.165682068259841, 2.202137131059317])
# -----Iteration for [ 2.0 ,  2.071866430436982 ] ----------
# function value: -0.035886818396317466
# c:  -1.8623971652437845
# d:  -0.12210848328495416
# Stop. F_derivative does not have 0
# X0:  interval([2.0, 2.071866430436982])
# -----Iteration for [ 2.165682068259841 ,  2.202137131059317 ] ----------
# function value: -0.17768927293102976
# c:  -1.3551091103651398
# d:  -0.4399609871476109
# Stop. F_derivative does not have 0
# X0:  interval([2.165682068259841, 2.202137131059317])
# -----Iteration for [ 2.2774023797571417 ,  2.4711538461538463 ] ----------
# function value: -0.3218476981675664
# c:  -3.0941613558756806
# d:  1.990975436997143
# X0:  interval([2.2774023797571417, 2.4711538461538463])
# U:  interval([-inf, 2.2702603643153365], [2.535931387117926, inf])
# X1:  interval()
# -----Iteration for [ 2.5267857142857144 ,  3.0 ] ----------
# function value: -0.31851142905544094
# c:  -5.846061862244898
# d:  7.678571428571427
# X0:  interval([2.5267857142857144, 3.0])
# U:  interval([-inf, 2.7089097817733583], [2.8048734153454262, inf])
# X1:  interval([2.5267857142857144, 2.7089097817733583], [2.8048734153454262, 3.0])
# -----Iteration for [ 2.5267857142857144 ,  2.7089097817733583 ] ----------
# function value: -0.38199311910081946
# c:  -2.3529792435252013
# d:  2.693148045933583
# X0:  interval([2.5267857142857144, 2.7089097817733583])
# U:  interval([-inf, 2.4555032989010677], [2.7596866341901376, inf])
# X1:  interval()
# -----Iteration for [ 2.8048734153454262 ,  3.0 ] ----------
# function value: -0.16749946219039202
# c:  -1.3980553716654534
# d:  4.341519015854885
# X0:  interval([2.8048734153454262, 3.0])
# U:  interval([-inf, 2.7826278177066053], [2.941017550363646, inf])
# X1:  interval([2.941017550363646, 3.0])
# -----Iteration for [ 2.941017550363646 ,  3.0 ] ----------
# function value: -0.056398902084531244
# c:  0.9487526946409446
# d:  2.7077893956362473
# Stop. F_derivative does not have 0
# X0:  interval([2.941017550363646, 3.0])
# -----Iteration for [ 3.0 ,  4 ] ----------
# function value: 1.875
# c:  -10.0
# d:  23.0
# X0:  interval([3.0, 4.0])
# U:  interval([-inf, 3.4184782608695654], [3.6875, inf])
# X1:  interval([3.0, 3.4184782608695654], [3.6875, 4.0])
# -----Iteration for [ 3.0 ,  3.4184782608695654 ] ----------
# function value: 0.5589820032220842
# c:  -3.0217391304347885
# d:  10.057980860113432
# X0:  interval([3.0, 3.4184782608695654])
# U:  interval([-inf, 3.1536631643441315], [3.394225980421947, inf])
# X1:  interval([3.0, 3.1536631643441315], [3.394225980421947, 3.4184782608695654])
# -----Iteration for [ 3.0 ,  3.1536631643441315 ] ----------
# function value: 0.1718259843008525
# c:  0.15604202787041999
# d:  4.836774062423125
# Stop. F_derivative does not have 0
# X0:  interval([3.0, 3.1536631643441315])
# -----Iteration for [ 3.394225980421947 ,  3.4184782608695654 ] ----------
# function value: 1.3751680726899025
# c:  4.540570888079188
# d:  5.32726909505007
# Stop. F_derivative does not have 0
# X0:  interval([3.394225980421947, 3.4184782608695654])
# -----Iteration for [ 3.6875 ,  4.0 ] ----------
# function value: 4.423919677734375
# c:  3.79296875
# d:  14.75
# Stop. F_derivative does not have 0
# X0:  interval([3.6875, 4.0])

# %%
def liniar_krafchyk(start, end, e):
  print('-----Iteration for [', start, ', ', end, '] ----------')
  global i
  global i_dividebytwo
  i = i + 1
  
  X0 = interval([start, end])
  mid = (start+end)/2;
  
  f = mid**3 - 3*mid + 2
  print('f: ', f)
  print('width: ', end - start)

  fX0 = X0*X0*X0 - 3*X0 + 2
  
  f_derivative = 3*mid**2 - 3
  F_derivative = 3*X0*X0 - 3
  
  check = end - start
  if check < e:
    print('FOUND X =', start, ' ', end)
    return
  
  if 0 in F_derivative:
    #print('0 in F_derivative')
    if mid - start > e:
      liniar_krafchyk(start, mid, e)
      liniar_krafchyk(mid, end, e)
      i_dividebytwo = i_dividebytwo + 1
    return
      
  U = mid - f/f_derivative + (1 - (F_derivative)/f_derivative)*(X0-mid)
  
  X1 = U & X0
  
  print('X0: ', X0);
  #print('U: ', U);
  #print('X1: ', X1);
  
  if X0 == X1:
    #print('X0 == X1')
    liniar_krafchyk(start, mid, e)
    liniar_krafchyk(mid, end, e)
    i_dividebytwo = i_dividebytwo + 1
    return
  
  [liniar_krafchyk(x.inf, x.sup, e) for x in X1]
  
  
print("Лінійний алгоритм Крафчика");
print("x^3 - 6*x^2 + 11*x - 6 = 0");
print("1, 2, 3");
x1 = 1;
x2 = 2;
x3 = 3;
e = 10**(-6)

a = -2.5;
b = -1.25;

print('[', a, ';', b, ']');
print("------------");

i = 0
i_dividebytwo = 0
  
liniar_krafchyk(a, b, e)

print("------------");
print('Iterations: ', i)
print('Iterations (divide by two): ', i_dividebytwo)
# Out:
# Лінійний алгоритм Крафчика
# x^3 - 6*x^2 + 11*x - 6 = 0
# 1, 2, 3
# [ -2.5 ; -1.25 ]
# ------------
# -----Iteration for [ -2.5 ,  -1.25 ] ----------
# f:  1.033203125
# width:  1.25
# X0:  interval([-2.5, -1.25])
# -----Iteration for [ -2.5 ,  -1.332556935817805 ] ----------
# f:  0.7120248481166875
# width:  1.167443064182195
# X0:  interval([-2.5, -1.332556935817805])
# -----Iteration for [ -2.5 ,  -1.4419662750549564 ] ----------
# f:  0.2561243239749622
# width:  1.0580337249450436
# X0:  interval([-2.5, -1.4419662750549564])
# -----Iteration for [ -2.434318805361475 ,  -1.5668373812912868 ] ----------
# f:  -0.005204845281985726
# width:  0.8674814240701882
# X0:  interval([-2.434318805361475, -1.5668373812912868])
# -----Iteration for [ -2.2778998597573685 ,  -1.72210058557438 ] ----------
# f:  -2.003993164301221e-06
# width:  0.5557992741829885
# X0:  interval([-2.2778998597573685, -1.72210058557438])
# -----Iteration for [ -2.110124820183006 ,  -1.889875179817061 ] ----------
# f:  -3.0020430585864233e-13
# width:  0.22024964036594485
# X0:  interval([-2.110124820183006, -1.889875179817061])
# -----Iteration for [ -2.0166151467324465 ,  -1.9833848532675535 ] ----------
# f:  0.0
# width:  0.033230293464892924
# X0:  interval([-2.0166151467324465, -1.9833848532675535])
# -----Iteration for [ -2.0003696130775643 ,  -1.9996303869224357 ] ----------
# f:  0.0
# width:  0.0007392261551286694
# X0:  interval([-2.0003696130775643, -1.9996303869224357])
# -----Iteration for [ -2.000000182168601 ,  -1.999999817831399 ] ----------
# f:  0.0
# width:  3.6433720218553844e-07
# FOUND X = -2.000000182168601   -1.999999817831399
# ------------
# Iterations:  9
# Iterations (divide by two):  0

# %%
# !pip install -q pyinterval
# Out:
#      |████████████████████████████████| 1.6MB 13.5MB/s
#   Building wheel for pyinterval (setup.py) ... done
#   Building wheel for crlibm (setup.py) ... done

# %%
import numpy as np
import pandas as pd
from interval import interval, inf, imath
from sympy.solvers import solve
from sympy import Symbol

# %%
class IntervalMatrix(object):
  @staticmethod
  def from_lists(arrayOfArrays):
    res = IntervalMatrix(len(arrayOfArrays), len(arrayOfArrays[0]))
    res.data = [[interval[bounds[0], bounds[1]] if isinstance(bounds, list) else interval[bounds] for bounds in row] for row in arrayOfArrays]
    return res
  
  def __init__(self, rows, columns):
    self.rows = rows
    self.columns = columns

  def __add__(self, other):
    res = IntervalMatrix(self.rows, self.columns)
    res.data = [[val1 + val2 for val1, val2 in zip(row1, row2)] for row1, row2 in zip(self.data, other.data)]
    return res

  def __sub__(self, other):
    res = IntervalMatrix(self.rows, self.columns)
    res.data = [[val1 - val2 for val1, val2 in zip(row1, row2)] for row1, row2 in zip(self.data, other.data)]
    return res

  def __mul__(self, other):
    if not self.columns == other.rows:
      raise "Nigga you blind or somethin?"
    res = IntervalMatrix(self.rows, other.columns)
    res.data = [[sum([v1 * v2 for v1,v2 in zip(leftRow, rightColumn)]) for rightColumn in other.transpose().data] for leftRow in self.data]
    return res

  def transpose(self):
    res = IntervalMatrix(self.columns, self.rows)
    res.data = [[self.data[j][i] for j in range(self.rows)] for i in range(self.columns)]
    return res

  def __getitem__(self, pos):
    row, column = pos
    return self.data[row][column]

  def __str__(self):
    res = ""
    for row in self.data:
      res += "|\t"
      for val in row:
        res += f"[{val[0].inf}; {val[0].sup}]"
      res += "\t|\n"
    return res

  def flatten(self):
    return [item for row in self.data for item in row]

# %%
##@title Алгоритм Мура (для системи 2х2)
#i or intr -> intervals for X and Y
def get_widths(i):
  return [intr[1] - intr[0] for intr in i]
def get_intervals(i):
  return [interval([intr[0], intr[1]]) for intr in i]
def get_middles(i):
  return np.array([[(intr[0] + intr[1]) / 2] for intr in i])
def get_f_mid(f, intr):
  mids = get_middles(intr)
  return np.array([[f[0](mids[0][0], mids[1][0])], [f[1](mids[0][0], mids[1][0])]])
def get_f_prime(f_prime, intervals):
  res = IntervalMatrix(2,2)
  res.data = [[f_prime[0][0](*intervals), f_prime[0][1](*intervals)], 
              [f_prime[1][0](*intervals), f_prime[1][1](*intervals)]]
  return res

def get_f_prime_inverse(f_prime, intervals):
  jakobian = [[f_prime[0][0](*intervals), f_prime[0][1](*intervals)], 
              [f_prime[1][0](*intervals), f_prime[1][1](*intervals)]]
  
  a_lower = np.array([[jakobian[0][0][0].inf, jakobian[0][1][0].inf],
                      [jakobian[1][0][0].inf, jakobian[1][1][0].inf]])
  a_upper = np.array([[jakobian[0][0][0].sup, jakobian[0][1][0].sup],
                      [jakobian[1][0][0].sup, jakobian[1][1][0].sup]])
  b_first_col = np.array([0, 1])
  b_second_col = np.array([1, 0])

  inverse_first_column_lower = np.linalg.solve(a_lower, b_first_col)
  inverse_first_column_upper = np.linalg.solve(a_upper, b_first_col)
  inverse_second_column_lower = np.linalg.solve(a_lower, b_second_col)
  inverse_second_column_upper = np.linalg.solve(a_upper, b_second_col)
  return IntervalMatrix.from_lists([[[inverse_first_column_lower[0], inverse_first_column_upper[0]], [inverse_second_column_lower[0], inverse_second_column_upper[0]]],
                         [[inverse_first_column_lower[1], inverse_first_column_upper[1]], [inverse_second_column_lower[1], inverse_second_column_upper[1]]]])

def init_datasource():
  return ([],[],[],[],[])

def append_datasource(
    xn_intervals,  
    widths,  
    middles,  
    u_intervals,  
    f_prime_matrices, 
    new_xn_intervals,
    new_widths,
    new_middles,
    new_u_intervals,
    new_f_prime_matrices):
  xn_intervals.append(new_xn_intervals)
  widths.append(new_widths)
  middles.append(new_middles)
  u_intervals.append(new_u_intervals)
  f_prime_matrices.append(new_f_prime_matrices)

#f - array of functions (lambdas)
#f_prime - matrix of derivatives of functions in f
#intervals - array of intervals for their respectful variables in the lambdas
def system_moore(f, f_prime, intervals, e):

  xn_intervals, widths, middles, u_intervals, f_prime_matrices = init_datasource()
  add_data = lambda new: append_datasource( xn_intervals, widths, middles, u_intervals, f_prime_matrices, *new)
  
  width = get_widths(intervals)

  if max(width) < e:
    add_data(
        (f"[{intervals[0][0]}; {intervals[0][1]}]\n[{intervals[1][0]}; {intervals[1][1]}]",
        f"ω(Xn) = {width[0]}\nω(Yn) = {width[1]}",
        "",
        "",
        f"Found X = [{intervals[0][0]}; {intervals[0][1]}]\nFound Y = [{intervals[1][0]}; {intervals[1][1]}]"))
    
    return (intervals, widths, middles, u_intervals, f_prime_matrices)

  X0 = get_intervals(intervals)
  mid = get_middles(intervals)
  f_mid = get_f_mid(f, intervals)
  
  if f_mid[0][0] == 0.0 and f_mid[1][0] == 0.0:
    #ділити на 4 сегменти
    #зліва знизу
    left_part_intervals = [[intervals[0][0], mid[0][0]], [intervals[1][0], mid[1][0]]]
    add_data(system_moore(f, f_prime, left_part_intervals, e))
    #справа знизу
    right_part_intervals = [[mid[0][0], intervals[0][1]], [intervals[1][0], mid[1][0]]]
    add_data(system_moore(f, f_prime, right_part_intervals, e))
    #зліва вгорі
    left_part_intervals = [[intervals[0][0], mid[0][0]], [intervals[1][0], mid[1][0]]]
    add_data(system_moore(f, f_prime, left_part_intervals, e))
    #справа вгорі
    right_part_intervals = [[mid[0][0], intervals[0][1]], [mid[1][0], intervals[1][1]]]
    add_data(system_moore(f, f_prime, right_part_intervals, e))

    
  f_derivative_inverse = get_f_prime_inverse(f_prime, X0)
  mid_interval = IntervalMatrix.from_lists([[m] for m in mid])
  f_mid_interval = IntervalMatrix.from_lists([[[f_mid[0][0], f_mid[0][0]]], 
                                       [[f_mid[1][0], f_mid[1][0]]]])

  U = mid_interval - f_derivative_inverse * f_mid_interval
  Xn = [[u & x0] for u, x0 in zip(U.flatten(), X0)]
  add_data(
      (f"Xn = [{intervals[0][0]}; {intervals[0][1]}]\nYn = [{intervals[1][0]}; {intervals[1][1]}]",
      f"ω(Xn) = {width[0]}\nω(Yn) = {width[1]}",
      f"mid Xn = {mid[0][0]}\nmid Yn = {mid[1][0]}",
      f"Ux = [{U[0,0][0].inf}; {U[0,0][0].sup}]\nUy = [{U[1,0][0].inf}; {U[1,0][0].sup}]",
      str(f_derivative_inverse)))
  
  for x in Xn[0]:
    for y in Xn[1]:
      append_datasource(
      xn_intervals, 
      widths, 
      middles, 
      u_intervals, 
      f_prime_matrices, 
      *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
  
  return (intervals, widths, middles, u_intervals, f_prime_matrices)

# %%
##@title Алгоритм Мура (задача для системи)
print("Системний алгоритм Мура");
print("f1(x,y) = 3*x - 5*y - 4 = 0");
print("f2(x,y) = x - 4*y + 1 = 0");
print("Корінь: (x, y) = (3, 1)");
print("Інтервали: X = [0; 6], Y = [-3; 3]")
print('-'*80);

e = 10**(-6)

f1 = lambda x, y: 3*x - 5*y - 4
f2 = lambda x, y: x - 4*y + 1

f1_der_x = lambda x, y: -1 - 5*y
f1_der_y = lambda x, y: 3*x - 9
f2_der_x = lambda x, y: 2 - 4*y
f2_der_y = lambda x, y: x - 3

X0 = [0, 6]
Y0 = [-3, 3]

f = np.array([f1, f2])
f_prime = np.array([[f1_der_x, f1_der_y], [f2_der_x, f2_der_y]])
intervals = np.array([X0, Y0])

intervals1, widths, middles, u_intervals, f_prime_matrices = system_moore(f, f_prime, intervals, e)

pd.set_option('display.max_rows', 999)  
df = pd.DataFrame({"Xn": intervals1, "ω(Xn)": widths, "x̅_n": middles, "U": u_intervals, "F'^-1(Xn)": f_prime_matrices})
display(df)
# Out:
# Системний алгоритм Мура
# f1(x,y) = 3*x - 5*y - 4 = 0
# f2(x,y) = x - 4*y + 1 = 0
# Корінь: (x, y) = (3, 1)
# Інтервали: X = [0; 6], Y = [-3; 3]
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in process(x)
#      97             try:
# ---> 98                 return make_component(*x if hasattr(x, '__iter__') else (x,))
#      99             except:
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in make_component(x, y)
#      93             else:
# ---> 94                 return cls.hull((cls.cast(x), cls.cast(y)))
#      95
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in cast(cls, x)
#     131                 return cls.new((cls.Component(fpu.down(lambda: y - 1), y),))
# --> 132         return cls.new((cls.Component(y, y),))
#     133
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in __new__(cls, inf, sup)
#     326         def __new__(cls, inf, sup):
# --> 327             if fpu.isnan(inf) or fpu.isnan(sup):
#     328                 return tuple.__new__(cls, (-fpu.infinity, +fpu.infinity))
#
# /usr/local/lib/python3.6/dist-packages/interval/fpu.py in isnan(x)
#      93     "Return True if x is nan."
# ---> 94     return x != x
#      95
#
# RecursionError: maximum recursion depth exceeded in comparison
#
# During handling of the above exception, another exception occurred:
#
# ComponentError                            Traceback (most recent call last)
# <ipython-input-8-563d1cedfe79> in <module>()
#      23 intervals = np.array([X0, Y0])
#      24
# ---> 25 intervals1, widths, middles, u_intervals, f_prime_matrices = system_moore(f, f_prime, intervals, e)
#      26
#      27 pd.set_option('display.max_rows', 999)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# ... (skipped 891 stack entries. Use sys.last_value and sys.last_traceback to investigate further.) ...
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#     114       u_intervals,
#     115       f_prime_matrices,
# --> 116       *system_moore(f, f_prime, [[x[0].inf, x[0].sup], [y[0].inf, y[0].sup]], e))
#     117
#     118   return (intervals, widths, middles, u_intervals, f_prime_matrices)
#
# <ipython-input-7-571ec013137b> in system_moore(f, f_prime, intervals, e)
#      92
#      93
# ---> 94   f_derivative_inverse = get_f_prime_inverse(f_prime, X0)
#      95   mid_interval = IntervalMatrix.from_lists([[m] for m in mid])
#      96   f_mid_interval = IntervalMatrix.from_lists([[[f_mid[0][0], f_mid[0][0]]],
#
# <ipython-input-7-571ec013137b> in get_f_prime_inverse(f_prime, intervals)
#      30   inverse_second_column_upper = np.linalg.solve(a_upper, b_second_col)
#      31   return IntervalMatrix.from_lists([[[inverse_first_column_lower[0], inverse_first_column_upper[0]], [inverse_second_column_lower[0], inverse_second_column_upper[0]]],
# ---> 32                          [[inverse_first_column_lower[1], inverse_first_column_upper[1]], [inverse_second_column_lower[1], inverse_second_column_upper[1]]]])
#      33
#      34 def init_datasource():
#
# <ipython-input-6-cc940a60d318> in from_lists(arrayOfArrays)
#       3   def from_lists(arrayOfArrays):
#       4     res = IntervalMatrix(len(arrayOfArrays), len(arrayOfArrays[0]))
# ----> 5     res.data = [[interval[bounds[0], bounds[1]] if isinstance(bounds, list) else interval[bounds] for bounds in row] for row in arrayOfArrays]
#       6     return res
#       7
#
# <ipython-input-6-cc940a60d318> in <listcomp>(.0)
#       3   def from_lists(arrayOfArrays):
#       4     res = IntervalMatrix(len(arrayOfArrays), len(arrayOfArrays[0]))
# ----> 5     res.data = [[interval[bounds[0], bounds[1]] if isinstance(bounds, list) else interval[bounds] for bounds in row] for row in arrayOfArrays]
#       6     return res
#       7
#
# <ipython-input-6-cc940a60d318> in <listcomp>(.0)
#       3   def from_lists(arrayOfArrays):
#       4     res = IntervalMatrix(len(arrayOfArrays), len(arrayOfArrays[0]))
# ----> 5     res.data = [[interval[bounds[0], bounds[1]] if isinstance(bounds, list) else interval[bounds] for bounds in row] for row in arrayOfArrays]
#       6     return res
#       7
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in __getitem__(self, arg)
#      50 class Metaclass(type):
#      51     def __getitem__(self, arg):
# ---> 52         return self(arg)
#      53
#      54
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in __new__(cls, *args)
#      99             except:
#     100                 raise cls.ComponentError("Invalid interval component: " + repr(x))
# --> 101         return cls.union(process(x) for x in args)
#     102
#     103     def __getnewargs__(self):
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in union(cls, intervals)
#     183
#     184         """
# --> 185         return cls._canonical(c for i in intervals for c in i)
#     186
#     187     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in _canonical(cls, components)
#     160     def _canonical(cls, components):
#     161         from operator import itemgetter
# --> 162         components = [c for c in components if c.inf <= c.sup]
#     163         components.sort(key=itemgetter(0))
#     164         l = []
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in <listcomp>(.0)
#     160     def _canonical(cls, components):
#     161         from operator import itemgetter
# --> 162         components = [c for c in components if c.inf <= c.sup]
#     163         components.sort(key=itemgetter(0))
#     164         l = []
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in <genexpr>(.0)
#     183
#     184         """
# --> 185         return cls._canonical(c for i in intervals for c in i)
#     186
#     187     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in <genexpr>(.0)
#      99             except:
#     100                 raise cls.ComponentError("Invalid interval component: " + repr(x))
# --> 101         return cls.union(process(x) for x in args)
#     102
#     103     def __getnewargs__(self):
#
# /usr/local/lib/python3.6/dist-packages/interval/__init__.py in process(x)
#      98                 return make_component(*x if hasattr(x, '__iter__') else (x,))
#      99             except:
# --> 100                 raise cls.ComponentError("Invalid interval component: " + repr(x))
#     101         return cls.union(process(x) for x in args)
#     102
#
# ComponentError: Invalid interval component: (-0.5454545454545453, 0.11999999999999998)
